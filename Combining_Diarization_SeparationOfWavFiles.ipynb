# %%
#!/usr/bin/env python
# coding: utf-8

# Copyright (c) Microsoft. All rights reserved.
# Licensed under the MIT license. See LICENSE.md file in the project root for full license information.

from typing import List

import logging
import sys
import requests
import time
import swagger_client as cris_client
import pandas as pd
import json
from datetime import timedelta

logging.basicConfig(stream=sys.stdout, level=logging.DEBUG, format="%(message)s")

# %%
# Your subscription key and region for the speech service
SUBSCRIPTION_KEY = "c45caa4f5ce640ceb402059defa818c3"
SERVICE_REGION = "eastus"

NAME = "Speech_Transcribe"
DESCRIPTION = "Transcribe and Diarize a telephone convevrsation"

LOCALE = "en-US"
RECORDINGS_BLOB_URI = "https://gtsblob.blob.core.windows.net/transcription/Samoy.wav"

# Set subscription information when doing transcription with custom models
ADAPTED_ACOUSTIC_ID = None  # guid of a custom acoustic model
ADAPTED_LANGUAGE_ID = None  # guid of a custom language model

# %%
def transcribe():
    logging.info("Starting transcription client...")

    # configure API key authorization: subscription_key
    configuration = cris_client.Configuration()
    configuration.api_key['Ocp-Apim-Subscription-Key'] = SUBSCRIPTION_KEY
    configuration.host = "https://{}.cris.ai".format(SERVICE_REGION)

    # create the client object and authenticate
    client = cris_client.ApiClient(configuration)

    # create an instance of the transcription api class
    transcription_api = cris_client.CustomSpeechTranscriptionsApi(api_client=client)

    # get all transcriptions for the subscription
    transcriptions: List[cris_client.Transcription] = transcription_api.get_transcriptions()

    logging.info("Deleting all existing completed transcriptions.")

    # delete all pre-existing completed transcriptions
    # if transcriptions are still running or not started, they will not be deleted
    for transcription in transcriptions:
        try:
            transcription_api.delete_transcription(transcription.id)
        except ValueError:
            # ignore swagger error on empty response message body: https://github.com/swagger-api/swagger-core/issues/2446
            pass

    # Specify transcription properties by passing a dict to the properties parameter. See
    # https://docs.microsoft.com/azure/cognitive-services/speech-service/batch-transcription#configuration-properties
    # for supported parameters.
    properties = {
        # 'PunctuationMode': 'DictatedAndAutomatic',
        # 'ProfanityFilterMode': 'Masked',
         'AddWordLevelTimestamps': 'True',
         'AddDiarization': 'True',
         'AddSentiment': True
        # 'TranscriptionResultsContainerUrl': "<results container>"
    }

    # Use base models for transcription. Comment this block if you are using a custom model.
    transcription_definition = cris_client.TranscriptionDefinition(
        name=NAME, description=DESCRIPTION, locale=LOCALE, recordings_url=RECORDINGS_BLOB_URI,
        properties=properties
    )

    # Uncomment this block to use custom models for transcription.
    # Model information (ADAPTED_ACOUSTIC_ID and ADAPTED_LANGUAGE_ID) must be set above.
    # if ADAPTED_ACOUSTIC_ID is None or ADAPTED_LANGUAGE_ID is None:
    #     logging.info("Custom model ids must be set to when using custom models")
    # transcription_definition = cris_client.TranscriptionDefinition(
    #     name=NAME, description=DESCRIPTION, locale=LOCALE, recordings_url=RECORDINGS_BLOB_URI,
    #     models=[cris_client.ModelIdentity(ADAPTED_ACOUSTIC_ID), cris_client.ModelIdentity(ADAPTED_LANGUAGE_ID)],
    #     properties=properties
    # )

    data, status, headers = transcription_api.create_transcription_with_http_info(transcription_definition)

    # extract transcription location from the headers
    transcription_location: str = headers["location"]

    # get the transcription Id from the location URI
    created_transcription: str = transcription_location.split('/')[-1]

    logging.info("Created new transcription with id {}".format(created_transcription))

    logging.info("Checking status.")

    completed = False

    while not completed:
        running, not_started = 0, 0

        # get all transcriptions for the user
        transcriptions: List[cris_client.Transcription] = transcription_api.get_transcriptions()

        # for each transcription in the list we check the status
        for transcription in transcriptions:
            if transcription.status in ("Failed", "Succeeded"):
                # we check to see if it was the transcription we created from this client
                if created_transcription != transcription.id:
                    continue

                completed = True

                if transcription.status == "Succeeded":
                    results_uri = transcription.results_urls["channel_0"]
                    results = requests.get(results_uri)
                    logging.info("Transcription succeeded. Results: ")
                    logging.info(results.content.decode("utf-8"))
                    return results.content.decode("utf-8")
                else:
                    logging.info("Transcription failed :{}.".format(transcription.status_message))
                    break
            elif transcription.status == "Running":
                running += 1
            elif transcription.status == "NotStarted":
                not_started += 1

        logging.info("Transcriptions status: "
                     "completed (this transcription): {}, {} running, {} not started yet".format(
                         completed, running, not_started))

        # wait for 5 seconds
        time.sleep(5)

    input("Press any key...")

# %%
if __name__ == "__main__":
    response1 = transcribe()
# Out:
# Starting transcription client...
# Deleting all existing completed transcriptions.
# Created new transcription with id d94ccaef-491e-43f8-af39-80b6ab5f072d
# Checking status.
# Transcriptions status: completed (this transcription): False, 0 running, 1 not started yet
# Transcriptions status: completed (this transcription): False, 0 running, 1 not started yet
# Transcriptions status: completed (this transcription): False, 0 running, 1 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcriptions status: completed (this transcription): False, 1 running, 0 not started yet
# Transcription succeeded. Results:
# {
#   "AudioFileResults": [
#     {
#       "AudioFileName": "Channel.0.wav",
#       "AudioFileUrl": null,
#       "AudioLengthInSeconds": 290.31,
#       "CombinedResults": [
#         {
#           "ChannelNumber": null,
#           "Lexical": "they will call good holder services my name is jimmy only had the card number please yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so can you switch the balances i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model credit union can i get the card number please for me to check yes it's a it's a gift card OK OK i'm now loading it here in our system one moment please in your name is you are i'm sorry for the delay just said still getting the information OK uhm here's something came up now this system and showing here that this card is broadway uh nothing back from this card is showing zero balance zero this action was made well actually first principle initial funds was fifty dollars in the first transaction made was at target uh it was made last or on a was this let me check the date december twenty seven two thousand and eighteen that was the first transaction and the balance went down to a thirty eight dollars and twenty eight cents second transaction made this month uh oh actually today january twentieth two thousand nineteen for ten dollars and five cents at dillards says here and the balance went down to twenty eight dollars and twenty three cents in that balance was was this was used at mercy she didn't do that so someone must have this i've had the card all day she didn't go to dillard's today that is so weird how about this yeah an this was made at midland texas showing here OK for going to check the what was the amount again to twenty eight dollars and thirty three cents so using that balance went down to zero when was that made at james avery what day today directions today james avery are you sure it's discard 'cause yeah yeah we didn't do him that's why i'm trying to tell you samantha today yeah well it's stolen they got the number stolen i'm holding the card oregon we didn't use it um i'm just giving you is uh the whatever information that we have hello are you sure was twenty twenty yeah january twentieth two thousand nineteen and nineteen nineteen OK this is twenty two thousand nineteen and yeah you said today he said today i'm sorry siri said OK oh i'm sorry about that but let me yeah so you change my bad biologies OK i was fine we've been here OK then she did use it last time like that's weird i'm holding the card OK that makes sense she just didn't know she already used it last year that makes sense i'm sorry about that man oh no you're fine i was like i am so confused now that i really yeah i said again uh two transactions made last year twenty two thousand nineteen and about ten thousand year old now so OK thank you do you have any car undercards aside from this no no no there are other ones yeah OK bye",
#           "ITN": "they will call good holder services my name is jimmy only had the card number please yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so can you switch the balances i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model credit union can i get the card number please for me to check yes it's a it's a gift card OK OK i'm now loading it here in our system one moment please in your name is you are i'm sorry for the delay just said still getting the information OK uhm here's something came up now this system and showing here that this card is broadway uh nothing back from this card is showing 0 balance 0 this action was made well actually first principle initial funds was $50 in the first transaction made was at target uh it was made last or on a was this let me check the date december 27 2018 that was the first transaction and the balance went down to a $3828 second transaction made this month uh oh actually today january 20th 2019 for $10 and five cents at dillards says here and the balance went down to $2823 in that balance was was this was used at mercy she didn't do that so someone must have this i've had the card all day she didn't go to dillard's today that is so weird how about this yeah an this was made at midland TX showing here OK for going to check the what was the amount again to $2833 so using that balance went down to 0 when was that made at james avery what day today directions today james avery are you sure it's discard 'cause yeah yeah we didn't do him that's why i'm trying to tell you samantha today yeah well it's stolen they got the number stolen i'm holding the card oregon we didn't use it um i'm just giving you is uh the whatever information that we have hello are you sure was 2020 yeah january 20th 2019 and 1919 OK this is 20 2019 and yeah you said today he said today i'm sorry siri said OK oh i'm sorry about that but let me yeah so you change my bad biologies OK i was fine we've been here OK then she did use it last time like that's weird i'm holding the card OK that makes sense she just didn't know she already used it last year that makes sense i'm sorry about that man oh no you're fine i was like i am so confused now that i really yeah i said again uh two transactions made last year 22019 and about 10000 year old now so OK thank you do you have any car undercards aside from this no no no there are other ones yeah OK bye",
#           "MaskedITN": "they will call good holder services my name is jimmy only had the card number please yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so can you switch the balances i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model credit union can i get the card number please for me to check yes it's a it's a gift card ok ok i'm now loading it here in our system one moment please in your name is you are i'm sorry for the delay just said still getting the information ok uhm here's something came up now this system and showing here that this card is broadway uh nothing back from this card is showing 0 balance 0 this action was made well actually first principle initial funds was $50 in the first transaction made was at target uh it was made last or on a was this let me check the date december 27 2018 that was the first transaction and the balance went down to a $3828 second transaction made this month uh oh actually today january 20th 2019 for $10 and five cents at dillard's says here and the balance went down to $2823 in that balance was was this was used at mercy she didn't do that so someone must have this i've had the card all day she didn't go to dillard's today that is so weird how about this yeah an this was made at midland tx showing here ok for going to check the what was the amount again to $2833 so using that balance went down to 0 when was that made at james avery what day today directions today james avery are you sure it's discard 'cause yeah yeah we didn't do him that's why i'm trying to tell you samantha today yeah well it's stolen they got the number stolen i'm holding the card oregon we didn't use it um i'm just giving you is uh the whatever information that we have hello are you sure was 2020 yeah january 20th 2019 and 1919 ok this is 20 2019 and yeah you said today he said today i'm sorry siri said ok oh i'm sorry about that but let me yeah so you change my bad biologies ok i was fine we've been here ok then she did use it last time like that's weird i'm holding the card ok that makes sense she just didn't know she already used it last year that makes sense i'm sorry about that man oh no you're fine i was like i am so confused now that i really yeah i said again uh two transactions made last year 22019 and about 10000 year old now so ok thank you do you have any car undercards aside from this no no no there are other ones yeah ok bye",
#           "Display": "They will call good Holder services. My name is Jimmy only had the card number please. Yes, but first let me ask my daughter receive this gift card for Christmas. Southwest Bank gift card and we're trying to get a balance on it. Keeps asking for a pin with course she doesn't have a pen, so. Can you switch the balances? I'm sorry about it. But uh, if you want to check the balance as soon as we service the the card, 'cause we service model. Credit union can I get the card number? Please for me to check? Yes, it's a. It's a gift card, OK? OK, I'm now loading it here in our system one moment please in your name is you are. I'm sorry for the delay, just said still getting the information. OK, uhm, here's something came up now this system and showing here that this card is Broadway, uh, nothing back from this card is showing 0 balance. 0. This action was made well actually. First principle, initial funds was $50 in the first transaction made was at Target. Uh, it was made last or on a was this? Let me check the date. December 27, 2018. That was the first transaction and the balance went down to a $38.28 second transaction made this month. Uh oh, actually today January 20th, 2019 for $10 and five cents at Dillard's, says here and the balance went down to $28.23 in that balance was. Was this was used at? Mercy, she didn't do that, so someone must have this. I've had the card all day. She didn't go to Dillard's today. That is so weird. How about this? Yeah. An this was made at Midland, TX. Showing here OK for going to check the what was the amount again to $28.33. So using that balance went down to 0. When was that made at James Avery? What day? Today Directions today. James Avery Are you sure it's discard 'cause? Yeah. Yeah, we didn't do him, that's why I'm trying to tell you, Samantha. Today Yeah, well, it's stolen. They got the number stolen. I'm holding the card Oregon, we didn't use it. Um, I'm just giving you is, uh, the whatever information that we have. Hello, Are you sure was 2020? Yeah, January 20th 2019. And 1919 OK this is 20. 2019 And Yeah, you said today he said today. I'm sorry. Siri said OK. Oh, I'm sorry about that. But let me yeah, so you change my bad biologies. OK, I was fine. We've been here. OK, then she did use it last time. Like that's weird. I'm holding the card. OK, that makes sense. She just didn't know she already used it last year. That makes sense. I'm sorry about. That man, Oh no, you're fine. I was like I am so confused. Now that I really yeah, I said again, uh, two transactions made last year. 22,019 and about 10,000 year old. Now so OK, thank you. Do you have any car undercards aside from this? No, no, no. There are other ones, yeah. OK. Bye."
#         }
#       ],
#       "SegmentResults": [
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 36500000,
#           "Duration": 38500000,
#           "OffsetInSeconds": 3.65,
#           "DurationInSeconds": 3.85,
#           "NBest": [
#             {
#               "Confidence": 0.780086637,
#               "Lexical": "they will call good holder services my name is jimmy only had the card number please",
#               "ITN": "they will call good holder services my name is jimmy only had the card number please",
#               "MaskedITN": "they will call good holder services my name is jimmy only had the card number please",
#               "Display": "They will call good Holder services. My name is Jimmy only had the card number please.",
#               "Sentiment": {
#                 "Negative": 0.0,
#                 "Neutral": 0.0,
#                 "Positive": 1.0
#               },
#               "Words": [
#                 {
#                   "Word": "they",
#                   "Offset": 36500000,
#                   "Duration": 1800000,
#                   "OffsetInSeconds": 3.65,
#                   "DurationInSeconds": 0.18,
#                   "Confidence": 0.91631
#                 },
#                 {
#                   "Word": "will",
#                   "Offset": 38300000,
#                   "Duration": 1500000,
#                   "OffsetInSeconds": 3.83,
#                   "DurationInSeconds": 0.15,
#                   "Confidence": 0.803557
#                 },
#                 {
#                   "Word": "call",
#                   "Offset": 39800000,
#                   "Duration": 2300000,
#                   "OffsetInSeconds": 3.98,
#                   "DurationInSeconds": 0.23,
#                   "Confidence": 0.849724
#                 },
#                 {
#                   "Word": "good",
#                   "Offset": 42100000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 4.21,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.958122
#                 },
#                 {
#                   "Word": "holder",
#                   "Offset": 43700000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 4.37,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.757125
#                 },
#                 {
#                   "Word": "services",
#                   "Offset": 46300000,
#                   "Duration": 4800000,
#                   "OffsetInSeconds": 4.63,
#                   "DurationInSeconds": 0.48,
#                   "Confidence": 0.968961
#                 },
#                 {
#                   "Word": "my",
#                   "Offset": 51100000,
#                   "Duration": 1400000,
#                   "OffsetInSeconds": 5.11,
#                   "DurationInSeconds": 0.14,
#                   "Confidence": 0.951298
#                 },
#                 {
#                   "Word": "name",
#                   "Offset": 52500000,
#                   "Duration": 1500000,
#                   "OffsetInSeconds": 5.25,
#                   "DurationInSeconds": 0.15,
#                   "Confidence": 0.971567
#                 },
#                 {
#                   "Word": "is",
#                   "Offset": 54000000,
#                   "Duration": 1200000,
#                   "OffsetInSeconds": 5.4,
#                   "DurationInSeconds": 0.12,
#                   "Confidence": 0.952004
#                 },
#                 {
#                   "Word": "jimmy",
#                   "Offset": 55200000,
#                   "Duration": 2800000,
#                   "OffsetInSeconds": 5.52,
#                   "DurationInSeconds": 0.28,
#                   "Confidence": 0.949641
#                 },
#                 {
#                   "Word": "only",
#                   "Offset": 58000000,
#                   "Duration": 2000000,
#                   "OffsetInSeconds": 5.8,
#                   "DurationInSeconds": 0.2,
#                   "Confidence": 0.921505
#                 },
#                 {
#                   "Word": "had",
#                   "Offset": 60000000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 6.0,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.923827
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 61700000,
#                   "Duration": 1000000,
#                   "OffsetInSeconds": 6.17,
#                   "DurationInSeconds": 0.1,
#                   "Confidence": 0.687347
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 62700000,
#                   "Duration": 4000000,
#                   "OffsetInSeconds": 6.27,
#                   "DurationInSeconds": 0.4,
#                   "Confidence": 0.973833
#                 },
#                 {
#                   "Word": "number",
#                   "Offset": 66700000,
#                   "Duration": 2800000,
#                   "OffsetInSeconds": 6.67,
#                   "DurationInSeconds": 0.28,
#                   "Confidence": 0.985657
#                 },
#                 {
#                   "Word": "please",
#                   "Offset": 69500000,
#                   "Duration": 5500000,
#                   "OffsetInSeconds": 6.95,
#                   "DurationInSeconds": 0.55,
#                   "Confidence": 0.99358
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 83700000,
#           "Duration": 126600000,
#           "OffsetInSeconds": 8.37,
#           "DurationInSeconds": 12.66,
#           "NBest": [
#             {
#               "Confidence": 0.922905564,
#               "Lexical": "yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so",
#               "ITN": "yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so",
#               "MaskedITN": "yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so",
#               "Display": "Yes, but first let me ask my daughter receive this gift card for Christmas. Southwest Bank gift card and we're trying to get a balance on it. Keeps asking for a pin with course she doesn't have a pen, so.",
#               "Sentiment": {
#                 "Negative": 0.999532,
#                 "Neutral": 0.0,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "yes",
#                   "Offset": 83700000,
#                   "Duration": 3700000,
#                   "OffsetInSeconds": 8.37,
#                   "DurationInSeconds": 0.37,
#                   "Confidence": 0.966876
#                 },
#                 {
#                   "Word": "but",
#                   "Offset": 87400000,
#                   "Duration": 2200000,
#                   "OffsetInSeconds": 8.74,
#                   "DurationInSeconds": 0.22,
#                   "Confidence": 0.731385
#                 },
#                 {
#                   "Word": "first",
#                   "Offset": 89600000,
#                   "Duration": 2900000,
#                   "OffsetInSeconds": 8.96,
#                   "DurationInSeconds": 0.29,
#                   "Confidence": 0.967292
#                 },
#                 {
#                   "Word": "let",
#                   "Offset": 92500000,
#                   "Duration": 1100000,
#                   "OffsetInSeconds": 9.25,
#                   "DurationInSeconds": 0.11,
#                   "Confidence": 0.9853
#                 },
#                 {
#                   "Word": "me",
#                   "Offset": 93600000,
#                   "Duration": 1000000,
#                   "OffsetInSeconds": 9.36,
#                   "DurationInSeconds": 0.1,
#                   "Confidence": 0.902764
#                 },
#                 {
#                   "Word": "ask",
#                   "Offset": 94600000,
#                   "Duration": 3000000,
#                   "OffsetInSeconds": 9.46,
#                   "DurationInSeconds": 0.3,
#                   "Confidence": 0.98925
#                 },
#                 {
#                   "Word": "my",
#                   "Offset": 97600000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 9.76,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.926288
#                 },
#                 {
#                   "Word": "daughter",
#                   "Offset": 99200000,
#                   "Duration": 3200000,
#                   "OffsetInSeconds": 9.92,
#                   "DurationInSeconds": 0.32,
#                   "Confidence": 0.97817
#                 },
#                 {
#                   "Word": "receive",
#                   "Offset": 102400000,
#                   "Duration": 4800000,
#                   "OffsetInSeconds": 10.24,
#                   "DurationInSeconds": 0.48,
#                   "Confidence": 0.975293
#                 },
#                 {
#                   "Word": "this",
#                   "Offset": 107200000,
#                   "Duration": 2200000,
#                   "OffsetInSeconds": 10.72,
#                   "DurationInSeconds": 0.22,
#                   "Confidence": 0.964716
#                 },
#                 {
#                   "Word": "gift",
#                   "Offset": 109400000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 10.94,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.985725
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 112000000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 11.2,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.97678
#                 },
#                 {
#                   "Word": "for",
#                   "Offset": 114600000,
#                   "Duration": 1400000,
#                   "OffsetInSeconds": 11.46,
#                   "DurationInSeconds": 0.14,
#                   "Confidence": 0.959422
#                 },
#                 {
#                   "Word": "christmas",
#                   "Offset": 116000000,
#                   "Duration": 5900000,
#                   "OffsetInSeconds": 11.6,
#                   "DurationInSeconds": 0.59,
#                   "Confidence": 0.995595
#                 },
#                 {
#                   "Word": "southwest",
#                   "Offset": 121900000,
#                   "Duration": 5500000,
#                   "OffsetInSeconds": 12.19,
#                   "DurationInSeconds": 0.55,
#                   "Confidence": 0.910037
#                 },
#                 {
#                   "Word": "bank",
#                   "Offset": 127400000,
#                   "Duration": 2300000,
#                   "OffsetInSeconds": 12.74,
#                   "DurationInSeconds": 0.23,
#                   "Confidence": 0.940531
#                 },
#                 {
#                   "Word": "gift",
#                   "Offset": 129700000,
#                   "Duration": 2500000,
#                   "OffsetInSeconds": 12.97,
#                   "DurationInSeconds": 0.25,
#                   "Confidence": 0.977282
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 132200000,
#                   "Duration": 6000000,
#                   "OffsetInSeconds": 13.22,
#                   "DurationInSeconds": 0.6,
#                   "Confidence": 0.991872
#                 },
#                 {
#                   "Word": "and",
#                   "Offset": 139000000,
#                   "Duration": 3800000,
#                   "OffsetInSeconds": 13.9,
#                   "DurationInSeconds": 0.38,
#                   "Confidence": 0.887017
#                 },
#                 {
#                   "Word": "we're",
#                   "Offset": 142800000,
#                   "Duration": 1400000,
#                   "OffsetInSeconds": 14.28,
#                   "DurationInSeconds": 0.14,
#                   "Confidence": 0.844312
#                 },
#                 {
#                   "Word": "trying",
#                   "Offset": 144200000,
#                   "Duration": 2900000,
#                   "OffsetInSeconds": 14.42,
#                   "DurationInSeconds": 0.29,
#                   "Confidence": 0.988977
#                 },
#                 {
#                   "Word": "to",
#                   "Offset": 147100000,
#                   "Duration": 700000,
#                   "OffsetInSeconds": 14.71,
#                   "DurationInSeconds": 0.07,
#                   "Confidence": 0.880221
#                 },
#                 {
#                   "Word": "get",
#                   "Offset": 147800000,
#                   "Duration": 2800000,
#                   "OffsetInSeconds": 14.78,
#                   "DurationInSeconds": 0.28,
#                   "Confidence": 0.984806
#                 },
#                 {
#                   "Word": "a",
#                   "Offset": 150600000,
#                   "Duration": 800000,
#                   "OffsetInSeconds": 15.06,
#                   "DurationInSeconds": 0.08,
#                   "Confidence": 0.971421
#                 },
#                 {
#                   "Word": "balance",
#                   "Offset": 151400000,
#                   "Duration": 10300000,
#                   "OffsetInSeconds": 15.14,
#                   "DurationInSeconds": 1.03,
#                   "Confidence": 0.993537
#                 },
#                 {
#                   "Word": "on",
#                   "Offset": 161900000,
#                   "Duration": 3600000,
#                   "OffsetInSeconds": 16.19,
#                   "DurationInSeconds": 0.36,
#                   "Confidence": 0.987268
#                 },
#                 {
#                   "Word": "it",
#                   "Offset": 165500000,
#                   "Duration": 2700000,
#                   "OffsetInSeconds": 16.55,
#                   "DurationInSeconds": 0.27,
#                   "Confidence": 0.659474
#                 },
#                 {
#                   "Word": "keeps",
#                   "Offset": 168200000,
#                   "Duration": 3000000,
#                   "OffsetInSeconds": 16.82,
#                   "DurationInSeconds": 0.3,
#                   "Confidence": 0.95688
#                 },
#                 {
#                   "Word": "asking",
#                   "Offset": 171200000,
#                   "Duration": 4100000,
#                   "OffsetInSeconds": 17.12,
#                   "DurationInSeconds": 0.41,
#                   "Confidence": 0.988451
#                 },
#                 {
#                   "Word": "for",
#                   "Offset": 175300000,
#                   "Duration": 1500000,
#                   "OffsetInSeconds": 17.53,
#                   "DurationInSeconds": 0.15,
#                   "Confidence": 0.936782
#                 },
#                 {
#                   "Word": "a",
#                   "Offset": 176800000,
#                   "Duration": 800000,
#                   "OffsetInSeconds": 17.68,
#                   "DurationInSeconds": 0.08,
#                   "Confidence": 0.978203
#                 },
#                 {
#                   "Word": "pin",
#                   "Offset": 177600000,
#                   "Duration": 4200000,
#                   "OffsetInSeconds": 17.76,
#                   "DurationInSeconds": 0.42,
#                   "Confidence": 0.97353
#                 },
#                 {
#                   "Word": "with",
#                   "Offset": 181800000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 18.18,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.907598
#                 },
#                 {
#                   "Word": "course",
#                   "Offset": 183500000,
#                   "Duration": 5500000,
#                   "OffsetInSeconds": 18.35,
#                   "DurationInSeconds": 0.55,
#                   "Confidence": 0.954158
#                 },
#                 {
#                   "Word": "she",
#                   "Offset": 189000000,
#                   "Duration": 3000000,
#                   "OffsetInSeconds": 18.9,
#                   "DurationInSeconds": 0.3,
#                   "Confidence": 0.977877
#                 },
#                 {
#                   "Word": "doesn't",
#                   "Offset": 192000000,
#                   "Duration": 3600000,
#                   "OffsetInSeconds": 19.2,
#                   "DurationInSeconds": 0.36,
#                   "Confidence": 0.984587
#                 },
#                 {
#                   "Word": "have",
#                   "Offset": 195600000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 19.56,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.97413
#                 },
#                 {
#                   "Word": "a",
#                   "Offset": 198200000,
#                   "Duration": 1000000,
#                   "OffsetInSeconds": 19.82,
#                   "DurationInSeconds": 0.1,
#                   "Confidence": 0.975284
#                 },
#                 {
#                   "Word": "pen",
#                   "Offset": 199200000,
#                   "Duration": 4800000,
#                   "OffsetInSeconds": 19.92,
#                   "DurationInSeconds": 0.48,
#                   "Confidence": 0.960164
#                 },
#                 {
#                   "Word": "so",
#                   "Offset": 204000000,
#                   "Duration": 6300000,
#                   "OffsetInSeconds": 20.4,
#                   "DurationInSeconds": 0.63,
#                   "Confidence": 0.987719
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 215800000,
#           "Duration": 18300000,
#           "OffsetInSeconds": 21.58,
#           "DurationInSeconds": 1.83,
#           "NBest": [
#             {
#               "Confidence": 0.847099,
#               "Lexical": "can you switch the balances",
#               "ITN": "can you switch the balances",
#               "MaskedITN": "can you switch the balances",
#               "Display": "Can you switch the balances?",
#               "Sentiment": {
#                 "Negative": 0.193801,
#                 "Neutral": 0.806182,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "can",
#                   "Offset": 215800000,
#                   "Duration": 2900000,
#                   "OffsetInSeconds": 21.58,
#                   "DurationInSeconds": 0.29,
#                   "Confidence": 0.974323
#                 },
#                 {
#                   "Word": "you",
#                   "Offset": 218700000,
#                   "Duration": 1300000,
#                   "OffsetInSeconds": 21.87,
#                   "DurationInSeconds": 0.13,
#                   "Confidence": 0.980541
#                 },
#                 {
#                   "Word": "switch",
#                   "Offset": 220000000,
#                   "Duration": 2500000,
#                   "OffsetInSeconds": 22.0,
#                   "DurationInSeconds": 0.25,
#                   "Confidence": 0.806996
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 222500000,
#                   "Duration": 1100000,
#                   "OffsetInSeconds": 22.25,
#                   "DurationInSeconds": 0.11,
#                   "Confidence": 0.873575
#                 },
#                 {
#                   "Word": "balances",
#                   "Offset": 223600000,
#                   "Duration": 10500000,
#                   "OffsetInSeconds": 22.36,
#                   "DurationInSeconds": 1.05,
#                   "Confidence": 0.98902
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 240900000,
#           "Duration": 59700000,
#           "OffsetInSeconds": 24.09,
#           "DurationInSeconds": 5.97,
#           "NBest": [
#             {
#               "Confidence": 0.847099,
#               "Lexical": "i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model",
#               "ITN": "i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model",
#               "MaskedITN": "i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model",
#               "Display": "I'm sorry about it. But uh, if you want to check the balance as soon as we service the the card, 'cause we service model.",
#               "Sentiment": {
#                 "Negative": 0.165329,
#                 "Neutral": 0.834648,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "i'm",
#                   "Offset": 240900000,
#                   "Duration": 3400000,
#                   "OffsetInSeconds": 24.09,
#                   "DurationInSeconds": 0.34,
#                   "Confidence": 0.907376
#                 },
#                 {
#                   "Word": "sorry",
#                   "Offset": 244300000,
#                   "Duration": 1900000,
#                   "OffsetInSeconds": 24.43,
#                   "DurationInSeconds": 0.19,
#                   "Confidence": 0.931071
#                 },
#                 {
#                   "Word": "about",
#                   "Offset": 246200000,
#                   "Duration": 2300000,
#                   "OffsetInSeconds": 24.62,
#                   "DurationInSeconds": 0.23,
#                   "Confidence": 0.961556
#                 },
#                 {
#                   "Word": "it",
#                   "Offset": 248500000,
#                   "Duration": 1100000,
#                   "OffsetInSeconds": 24.85,
#                   "DurationInSeconds": 0.11,
#                   "Confidence": 0.955459
#                 },
#                 {
#                   "Word": "but",
#                   "Offset": 249600000,
#                   "Duration": 2300000,
#                   "OffsetInSeconds": 24.96,
#                   "DurationInSeconds": 0.23,
#                   "Confidence": 0.988847
#                 },
#                 {
#                   "Word": "uh",
#                   "Offset": 252100000,
#                   "Duration": 3800000,
#                   "OffsetInSeconds": 25.21,
#                   "DurationInSeconds": 0.38,
#                   "Confidence": 0.979274
#                 },
#                 {
#                   "Word": "if",
#                   "Offset": 255900000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 25.59,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.884578
#                 },
#                 {
#                   "Word": "you",
#                   "Offset": 257600000,
#                   "Duration": 900000,
#                   "OffsetInSeconds": 25.76,
#                   "DurationInSeconds": 0.09,
#                   "Confidence": 0.978265
#                 },
#                 {
#                   "Word": "want",
#                   "Offset": 258500000,
#                   "Duration": 1400000,
#                   "OffsetInSeconds": 25.85,
#                   "DurationInSeconds": 0.14,
#                   "Confidence": 0.967638
#                 },
#                 {
#                   "Word": "to",
#                   "Offset": 259900000,
#                   "Duration": 800000,
#                   "OffsetInSeconds": 25.99,
#                   "DurationInSeconds": 0.08,
#                   "Confidence": 0.400911
#                 },
#                 {
#                   "Word": "check",
#                   "Offset": 260700000,
#                   "Duration": 2000000,
#                   "OffsetInSeconds": 26.07,
#                   "DurationInSeconds": 0.2,
#                   "Confidence": 0.9743
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 262700000,
#                   "Duration": 1200000,
#                   "OffsetInSeconds": 26.27,
#                   "DurationInSeconds": 0.12,
#                   "Confidence": 0.916953
#                 },
#                 {
#                   "Word": "balance",
#                   "Offset": 263900000,
#                   "Duration": 5000000,
#                   "OffsetInSeconds": 26.39,
#                   "DurationInSeconds": 0.5,
#                   "Confidence": 0.94055
#                 },
#                 {
#                   "Word": "as",
#                   "Offset": 268900000,
#                   "Duration": 1100000,
#                   "OffsetInSeconds": 26.89,
#                   "DurationInSeconds": 0.11,
#                   "Confidence": 0.741804
#                 },
#                 {
#                   "Word": "soon",
#                   "Offset": 270000000,
#                   "Duration": 1900000,
#                   "OffsetInSeconds": 27.0,
#                   "DurationInSeconds": 0.19,
#                   "Confidence": 0.985531
#                 },
#                 {
#                   "Word": "as",
#                   "Offset": 271900000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 27.19,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.983773
#                 },
#                 {
#                   "Word": "we",
#                   "Offset": 273500000,
#                   "Duration": 2200000,
#                   "OffsetInSeconds": 27.35,
#                   "DurationInSeconds": 0.22,
#                   "Confidence": 0.980633
#                 },
#                 {
#                   "Word": "service",
#                   "Offset": 275700000,
#                   "Duration": 3800000,
#                   "OffsetInSeconds": 27.57,
#                   "DurationInSeconds": 0.38,
#                   "Confidence": 0.863328
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 279500000,
#                   "Duration": 3800000,
#                   "OffsetInSeconds": 27.95,
#                   "DurationInSeconds": 0.38,
#                   "Confidence": 0.867148
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 283300000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 28.33,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.88208
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 284900000,
#                   "Duration": 5800000,
#                   "OffsetInSeconds": 28.49,
#                   "DurationInSeconds": 0.58,
#                   "Confidence": 0.979923
#                 },
#                 {
#                   "Word": "'cause",
#                   "Offset": 290700000,
#                   "Duration": 2400000,
#                   "OffsetInSeconds": 29.07,
#                   "DurationInSeconds": 0.24,
#                   "Confidence": 0.920268
#                 },
#                 {
#                   "Word": "we",
#                   "Offset": 293100000,
#                   "Duration": 1000000,
#                   "OffsetInSeconds": 29.31,
#                   "DurationInSeconds": 0.1,
#                   "Confidence": 0.913274
#                 },
#                 {
#                   "Word": "service",
#                   "Offset": 294100000,
#                   "Duration": 3200000,
#                   "OffsetInSeconds": 29.41,
#                   "DurationInSeconds": 0.32,
#                   "Confidence": 0.934722
#                 },
#                 {
#                   "Word": "model",
#                   "Offset": 297300000,
#                   "Duration": 3300000,
#                   "OffsetInSeconds": 29.73,
#                   "DurationInSeconds": 0.33,
#                   "Confidence": 0.961283
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 317100000,
#           "Duration": 30600000,
#           "OffsetInSeconds": 31.71,
#           "DurationInSeconds": 3.06,
#           "NBest": [
#             {
#               "Confidence": 0.8778057,
#               "Lexical": "credit union can i get the card number please for me to check",
#               "ITN": "credit union can i get the card number please for me to check",
#               "MaskedITN": "credit union can i get the card number please for me to check",
#               "Display": "Credit union can I get the card number? Please for me to check?",
#               "Sentiment": {
#                 "Negative": 1.0,
#                 "Neutral": 0.0,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "credit",
#                   "Offset": 317100000,
#                   "Duration": 3500000,
#                   "OffsetInSeconds": 31.71,
#                   "DurationInSeconds": 0.35,
#                   "Confidence": 0.952136
#                 },
#                 {
#                   "Word": "union",
#                   "Offset": 320600000,
#                   "Duration": 3300000,
#                   "OffsetInSeconds": 32.06,
#                   "DurationInSeconds": 0.33,
#                   "Confidence": 0.976743
#                 },
#                 {
#                   "Word": "can",
#                   "Offset": 326000000,
#                   "Duration": 1900000,
#                   "OffsetInSeconds": 32.6,
#                   "DurationInSeconds": 0.19,
#                   "Confidence": 0.544784
#                 },
#                 {
#                   "Word": "i",
#                   "Offset": 327900000,
#                   "Duration": 400000,
#                   "OffsetInSeconds": 32.79,
#                   "DurationInSeconds": 0.04,
#                   "Confidence": 0.931711
#                 },
#                 {
#                   "Word": "get",
#                   "Offset": 328300000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 32.83,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.97499
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 330000000,
#                   "Duration": 900000,
#                   "OffsetInSeconds": 33.0,
#                   "DurationInSeconds": 0.09,
#                   "Confidence": 0.505417
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 330900000,
#                   "Duration": 3000000,
#                   "OffsetInSeconds": 33.09,
#                   "DurationInSeconds": 0.3,
#                   "Confidence": 0.959446
#                 },
#                 {
#                   "Word": "number",
#                   "Offset": 333900000,
#                   "Duration": 2400000,
#                   "OffsetInSeconds": 33.39,
#                   "DurationInSeconds": 0.24,
#                   "Confidence": 0.98268
#                 },
#                 {
#                   "Word": "please",
#                   "Offset": 336300000,
#                   "Duration": 3000000,
#                   "OffsetInSeconds": 33.63,
#                   "DurationInSeconds": 0.3,
#                   "Confidence": 0.945495
#                 },
#                 {
#                   "Word": "for",
#                   "Offset": 339300000,
#                   "Duration": 1800000,
#                   "OffsetInSeconds": 33.93,
#                   "DurationInSeconds": 0.18,
#                   "Confidence": 0.97598
#                 },
#                 {
#                   "Word": "me",
#                   "Offset": 341100000,
#                   "Duration": 800000,
#                   "OffsetInSeconds": 34.11,
#                   "DurationInSeconds": 0.08,
#                   "Confidence": 0.635538
#                 },
#                 {
#                   "Word": "to",
#                   "Offset": 341900000,
#                   "Duration": 1200000,
#                   "OffsetInSeconds": 34.19,
#                   "DurationInSeconds": 0.12,
#                   "Confidence": 0.784154
#                 },
#                 {
#                   "Word": "check",
#                   "Offset": 343100000,
#                   "Duration": 4600000,
#                   "OffsetInSeconds": 34.31,
# ...
#                   "DurationInSeconds": 0.43,
#                   "Confidence": 0.978851
#                 },
#                 {
#                   "Word": "uh",
#                   "Offset": 2668000000,
#                   "Duration": 3300000,
#                   "OffsetInSeconds": 266.8,
#                   "DurationInSeconds": 0.33,
#                   "Confidence": 0.790811
#                 },
#                 {
#                   "Word": "two",
#                   "Offset": 2671300000,
#                   "Duration": 1400000,
#                   "OffsetInSeconds": 267.13,
#                   "DurationInSeconds": 0.14,
#                   "Confidence": 0.815722
#                 },
#                 {
#                   "Word": "transactions",
#                   "Offset": 2672700000,
#                   "Duration": 8000000,
#                   "OffsetInSeconds": 267.27,
#                   "DurationInSeconds": 0.8,
#                   "Confidence": 0.968749
#                 },
#                 {
#                   "Word": "made",
#                   "Offset": 2680700000,
#                   "Duration": 4200000,
#                   "OffsetInSeconds": 268.07,
#                   "DurationInSeconds": 0.42,
#                   "Confidence": 0.980355
#                 },
#                 {
#                   "Word": "last",
#                   "Offset": 2684900000,
#                   "Duration": 3300000,
#                   "OffsetInSeconds": 268.49,
#                   "DurationInSeconds": 0.33,
#                   "Confidence": 0.981472
#                 },
#                 {
#                   "Word": "year",
#                   "Offset": 2688200000,
#                   "Duration": 3100000,
#                   "OffsetInSeconds": 268.82,
#                   "DurationInSeconds": 0.31,
#                   "Confidence": 0.984506
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 2707300000,
#           "Duration": 37200000,
#           "OffsetInSeconds": 270.73,
#           "DurationInSeconds": 3.72,
#           "NBest": [
#             {
#               "Confidence": 0.8469867,
#               "Lexical": "twenty two thousand nineteen and about ten thousand year old",
#               "ITN": "22019 and about 10000 year old",
#               "MaskedITN": "22019 and about 10000 year old",
#               "Display": "22,019 and about 10,000 year old.",
#               "Sentiment": {
#                 "Negative": 0.17136,
#                 "Neutral": 0.828626,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "twenty",
#                   "Offset": 2707300000,
#                   "Duration": 3400000,
#                   "OffsetInSeconds": 270.73,
#                   "DurationInSeconds": 0.34,
#                   "Confidence": 0.86526
#                 },
#                 {
#                   "Word": "two",
#                   "Offset": 2710700000,
#                   "Duration": 1800000,
#                   "OffsetInSeconds": 271.07,
#                   "DurationInSeconds": 0.18,
#                   "Confidence": 0.868109
#                 },
#                 {
#                   "Word": "thousand",
#                   "Offset": 2712500000,
#                   "Duration": 4000000,
#                   "OffsetInSeconds": 271.25,
#                   "DurationInSeconds": 0.4,
#                   "Confidence": 0.991141
#                 },
#                 {
#                   "Word": "nineteen",
#                   "Offset": 2716500000,
#                   "Duration": 8800000,
#                   "OffsetInSeconds": 271.65,
#                   "DurationInSeconds": 0.88,
#                   "Confidence": 0.994623
#                 },
#                 {
#                   "Word": "and",
#                   "Offset": 2728200000,
#                   "Duration": 3500000,
#                   "OffsetInSeconds": 272.82,
#                   "DurationInSeconds": 0.35,
#                   "Confidence": 0.931962
#                 },
#                 {
#                   "Word": "about",
#                   "Offset": 2731700000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 273.17,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.896901
#                 },
#                 {
#                   "Word": "ten",
#                   "Offset": 2734300000,
#                   "Duration": 2000000,
#                   "OffsetInSeconds": 273.43,
#                   "DurationInSeconds": 0.2,
#                   "Confidence": 0.648173
#                 },
#                 {
#                   "Word": "thousand",
#                   "Offset": 2736300000,
#                   "Duration": 4400000,
#                   "OffsetInSeconds": 273.63,
#                   "DurationInSeconds": 0.44,
#                   "Confidence": 0.954474
#                 },
#                 {
#                   "Word": "year",
#                   "Offset": 2740700000,
#                   "Duration": 2200000,
#                   "OffsetInSeconds": 274.07,
#                   "DurationInSeconds": 0.22,
#                   "Confidence": 0.903698
#                 },
#                 {
#                   "Word": "old",
#                   "Offset": 2742900000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 274.29,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.987325
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 2744500000,
#           "Duration": 29200000,
#           "OffsetInSeconds": 274.45,
#           "DurationInSeconds": 2.92,
#           "NBest": [
#             {
#               "Confidence": 0.8469867,
#               "Lexical": "now so OK thank you",
#               "ITN": "now so OK thank you",
#               "MaskedITN": "now so ok thank you",
#               "Display": "Now so OK, thank you.",
#               "Sentiment": {
#                 "Negative": 0.0,
#                 "Neutral": 0.0,
#                 "Positive": 1.0
#               },
#               "Words": [
#                 {
#                   "Word": "now",
#                   "Offset": 2744500000,
#                   "Duration": 4600000,
#                   "OffsetInSeconds": 274.45,
#                   "DurationInSeconds": 0.46,
#                   "Confidence": 0.983755
#                 },
#                 {
#                   "Word": "so",
#                   "Offset": 2749300000,
#                   "Duration": 4000000,
#                   "OffsetInSeconds": 274.93,
#                   "DurationInSeconds": 0.4,
#                   "Confidence": 0.942321
#                 },
#                 {
#                   "Word": "OK",
#                   "Offset": 2754700000,
#                   "Duration": 7700000,
#                   "OffsetInSeconds": 275.47,
#                   "DurationInSeconds": 0.77,
#                   "Confidence": 0.987758
#                 },
#                 {
#                   "Word": "thank",
#                   "Offset": 2762600000,
#                   "Duration": 5300000,
#                   "OffsetInSeconds": 276.26,
#                   "DurationInSeconds": 0.53,
#                   "Confidence": 0.992049
#                 },
#                 {
#                   "Word": "you",
#                   "Offset": 2767900000,
#                   "Duration": 5800000,
#                   "OffsetInSeconds": 276.79,
#                   "DurationInSeconds": 0.58,
#                   "Confidence": 0.994294
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 2777500000,
#           "Duration": 24200000,
#           "OffsetInSeconds": 277.75,
#           "DurationInSeconds": 2.42,
#           "NBest": [
#             {
#               "Confidence": 0.8469867,
#               "Lexical": "do you have any car undercards aside from this",
#               "ITN": "do you have any car undercards aside from this",
#               "MaskedITN": "do you have any car undercards aside from this",
#               "Display": "Do you have any car undercards aside from this?",
#               "Sentiment": {
#                 "Negative": 0.185465,
#                 "Neutral": 0.814511,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "do",
#                   "Offset": 2777500000,
#                   "Duration": 2300000,
#                   "OffsetInSeconds": 277.75,
#                   "DurationInSeconds": 0.23,
#                   "Confidence": 0.688052
#                 },
#                 {
#                   "Word": "you",
#                   "Offset": 2779800000,
#                   "Duration": 600000,
#                   "OffsetInSeconds": 277.98,
#                   "DurationInSeconds": 0.06,
#                   "Confidence": 0.943639
#                 },
#                 {
#                   "Word": "have",
#                   "Offset": 2780400000,
#                   "Duration": 1500000,
#                   "OffsetInSeconds": 278.04,
#                   "DurationInSeconds": 0.15,
#                   "Confidence": 0.933231
#                 },
#                 {
#                   "Word": "any",
#                   "Offset": 2781900000,
#                   "Duration": 2000000,
#                   "OffsetInSeconds": 278.19,
#                   "DurationInSeconds": 0.2,
#                   "Confidence": 0.933061
#                 },
#                 {
#                   "Word": "car",
#                   "Offset": 2783900000,
#                   "Duration": 3400000,
#                   "OffsetInSeconds": 278.39,
#                   "DurationInSeconds": 0.34,
#                   "Confidence": 0.915883
#                 },
#                 {
#                   "Word": "undercards",
#                   "Offset": 2787300000,
#                   "Duration": 5600000,
#                   "OffsetInSeconds": 278.73,
#                   "DurationInSeconds": 0.56,
#                   "Confidence": 0.75935
#                 },
#                 {
#                   "Word": "aside",
#                   "Offset": 2792900000,
#                   "Duration": 2500000,
#                   "OffsetInSeconds": 279.29,
#                   "DurationInSeconds": 0.25,
#                   "Confidence": 0.705109
#                 },
#                 {
#                   "Word": "from",
#                   "Offset": 2795400000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 279.54,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.980633
#                 },
#                 {
#                   "Word": "this",
#                   "Offset": 2797100000,
#                   "Duration": 4600000,
#                   "OffsetInSeconds": 279.71,
#                   "DurationInSeconds": 0.46,
#                   "Confidence": 0.986216
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 2809600000,
#           "Duration": 25500000,
#           "OffsetInSeconds": 280.96,
#           "DurationInSeconds": 2.55,
#           "NBest": [
#             {
#               "Confidence": 0.8469867,
#               "Lexical": "no no no there are other ones yeah",
#               "ITN": "no no no there are other ones yeah",
#               "MaskedITN": "no no no there are other ones yeah",
#               "Display": "No, no, no. There are other ones, yeah.",
#               "Sentiment": {
#                 "Negative": 0.14846,
#                 "Neutral": 0.851514,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "no",
#                   "Offset": 2809600000,
#                   "Duration": 2800000,
#                   "OffsetInSeconds": 280.96,
#                   "DurationInSeconds": 0.28,
#                   "Confidence": 0.860187
#                 },
#                 {
#                   "Word": "no",
#                   "Offset": 2812400000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 281.24,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.981253
#                 },
#                 {
#                   "Word": "no",
#                   "Offset": 2814100000,
#                   "Duration": 4000000,
#                   "OffsetInSeconds": 281.41,
#                   "DurationInSeconds": 0.4,
#                   "Confidence": 0.991055
#                 },
#                 {
#                   "Word": "there",
#                   "Offset": 2818400000,
#                   "Duration": 2100000,
#                   "OffsetInSeconds": 281.84,
#                   "DurationInSeconds": 0.21,
#                   "Confidence": 0.593303
#                 },
#                 {
#                   "Word": "are",
#                   "Offset": 2820500000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 282.05,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.961326
#                 },
#                 {
#                   "Word": "other",
#                   "Offset": 2822100000,
#                   "Duration": 2400000,
#                   "OffsetInSeconds": 282.21,
#                   "DurationInSeconds": 0.24,
#                   "Confidence": 0.978128
#                 },
#                 {
#                   "Word": "ones",
#                   "Offset": 2824500000,
#                   "Duration": 4600000,
#                   "OffsetInSeconds": 282.45,
#                   "DurationInSeconds": 0.46,
#                   "Confidence": 0.977808
#                 },
#                 {
#                   "Word": "yeah",
#                   "Offset": 2829700000,
#                   "Duration": 5400000,
#                   "OffsetInSeconds": 282.97,
#                   "DurationInSeconds": 0.54,
#                   "Confidence": 0.963212
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 2863900000,
#           "Duration": 6100000,
#           "OffsetInSeconds": 286.39,
#           "DurationInSeconds": 0.61,
#           "NBest": [
#             {
#               "Confidence": 0.3113904,
#               "Lexical": "OK",
#               "ITN": "OK",
#               "MaskedITN": "ok",
#               "Display": "OK.",
#               "Sentiment": {
#                 "Negative": 0.128167,
#                 "Neutral": 0.871816,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "OK",
#                   "Offset": 2863900000,
#                   "Duration": 6100000,
#                   "OffsetInSeconds": 286.39,
#                   "DurationInSeconds": 0.61,
#                   "Confidence": 0.843836
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 2877100000,
#           "Duration": 3600000,
#           "OffsetInSeconds": 287.71,
#           "DurationInSeconds": 0.36,
#           "NBest": [
#             {
#               "Confidence": 0.426483065,
#               "Lexical": "bye",
#               "ITN": "bye",
#               "MaskedITN": "bye",
#               "Display": "Bye.",
#               "Sentiment": {
#                 "Negative": 0.133701,
#                 "Neutral": 0.866284,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "bye",
#                   "Offset": 2877100000,
#                   "Duration": 3600000,
#                   "OffsetInSeconds": 287.71,
#                   "DurationInSeconds": 0.36,
#                   "Confidence": 0.886997
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
print(response1)
# Out:
# {
#   "AudioFileResults": [
#     {
#       "AudioFileName": "Channel.0.wav",
#       "AudioFileUrl": null,
#       "AudioLengthInSeconds": 290.31,
#       "CombinedResults": [
#         {
#           "ChannelNumber": null,
#           "Lexical": "they will call good holder services my name is jimmy only had the card number please yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so can you switch the balances i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model credit union can i get the card number please for me to check yes it's a it's a gift card OK OK i'm now loading it here in our system one moment please in your name is you are i'm sorry for the delay just said still getting the information OK uhm here's something came up now this system and showing here that this card is broadway uh nothing back from this card is showing zero balance zero this action was made well actually first principle initial funds was fifty dollars in the first transaction made was at target uh it was made last or on a was this let me check the date december twenty seven two thousand and eighteen that was the first transaction and the balance went down to a thirty eight dollars and twenty eight cents second transaction made this month uh oh actually today january twentieth two thousand nineteen for ten dollars and five cents at dillards says here and the balance went down to twenty eight dollars and twenty three cents in that balance was was this was used at mercy she didn't do that so someone must have this i've had the card all day she didn't go to dillard's today that is so weird how about this yeah an this was made at midland texas showing here OK for going to check the what was the amount again to twenty eight dollars and thirty three cents so using that balance went down to zero when was that made at james avery what day today directions today james avery are you sure it's discard 'cause yeah yeah we didn't do him that's why i'm trying to tell you samantha today yeah well it's stolen they got the number stolen i'm holding the card oregon we didn't use it um i'm just giving you is uh the whatever information that we have hello are you sure was twenty twenty yeah january twentieth two thousand nineteen and nineteen nineteen OK this is twenty two thousand nineteen and yeah you said today he said today i'm sorry siri said OK oh i'm sorry about that but let me yeah so you change my bad biologies OK i was fine we've been here OK then she did use it last time like that's weird i'm holding the card OK that makes sense she just didn't know she already used it last year that makes sense i'm sorry about that man oh no you're fine i was like i am so confused now that i really yeah i said again uh two transactions made last year twenty two thousand nineteen and about ten thousand year old now so OK thank you do you have any car undercards aside from this no no no there are other ones yeah OK bye",
#           "ITN": "they will call good holder services my name is jimmy only had the card number please yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so can you switch the balances i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model credit union can i get the card number please for me to check yes it's a it's a gift card OK OK i'm now loading it here in our system one moment please in your name is you are i'm sorry for the delay just said still getting the information OK uhm here's something came up now this system and showing here that this card is broadway uh nothing back from this card is showing 0 balance 0 this action was made well actually first principle initial funds was $50 in the first transaction made was at target uh it was made last or on a was this let me check the date december 27 2018 that was the first transaction and the balance went down to a $3828 second transaction made this month uh oh actually today january 20th 2019 for $10 and five cents at dillards says here and the balance went down to $2823 in that balance was was this was used at mercy she didn't do that so someone must have this i've had the card all day she didn't go to dillard's today that is so weird how about this yeah an this was made at midland TX showing here OK for going to check the what was the amount again to $2833 so using that balance went down to 0 when was that made at james avery what day today directions today james avery are you sure it's discard 'cause yeah yeah we didn't do him that's why i'm trying to tell you samantha today yeah well it's stolen they got the number stolen i'm holding the card oregon we didn't use it um i'm just giving you is uh the whatever information that we have hello are you sure was 2020 yeah january 20th 2019 and 1919 OK this is 20 2019 and yeah you said today he said today i'm sorry siri said OK oh i'm sorry about that but let me yeah so you change my bad biologies OK i was fine we've been here OK then she did use it last time like that's weird i'm holding the card OK that makes sense she just didn't know she already used it last year that makes sense i'm sorry about that man oh no you're fine i was like i am so confused now that i really yeah i said again uh two transactions made last year 22019 and about 10000 year old now so OK thank you do you have any car undercards aside from this no no no there are other ones yeah OK bye",
#           "MaskedITN": "they will call good holder services my name is jimmy only had the card number please yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so can you switch the balances i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model credit union can i get the card number please for me to check yes it's a it's a gift card ok ok i'm now loading it here in our system one moment please in your name is you are i'm sorry for the delay just said still getting the information ok uhm here's something came up now this system and showing here that this card is broadway uh nothing back from this card is showing 0 balance 0 this action was made well actually first principle initial funds was $50 in the first transaction made was at target uh it was made last or on a was this let me check the date december 27 2018 that was the first transaction and the balance went down to a $3828 second transaction made this month uh oh actually today january 20th 2019 for $10 and five cents at dillard's says here and the balance went down to $2823 in that balance was was this was used at mercy she didn't do that so someone must have this i've had the card all day she didn't go to dillard's today that is so weird how about this yeah an this was made at midland tx showing here ok for going to check the what was the amount again to $2833 so using that balance went down to 0 when was that made at james avery what day today directions today james avery are you sure it's discard 'cause yeah yeah we didn't do him that's why i'm trying to tell you samantha today yeah well it's stolen they got the number stolen i'm holding the card oregon we didn't use it um i'm just giving you is uh the whatever information that we have hello are you sure was 2020 yeah january 20th 2019 and 1919 ok this is 20 2019 and yeah you said today he said today i'm sorry siri said ok oh i'm sorry about that but let me yeah so you change my bad biologies ok i was fine we've been here ok then she did use it last time like that's weird i'm holding the card ok that makes sense she just didn't know she already used it last year that makes sense i'm sorry about that man oh no you're fine i was like i am so confused now that i really yeah i said again uh two transactions made last year 22019 and about 10000 year old now so ok thank you do you have any car undercards aside from this no no no there are other ones yeah ok bye",
#           "Display": "They will call good Holder services. My name is Jimmy only had the card number please. Yes, but first let me ask my daughter receive this gift card for Christmas. Southwest Bank gift card and we're trying to get a balance on it. Keeps asking for a pin with course she doesn't have a pen, so. Can you switch the balances? I'm sorry about it. But uh, if you want to check the balance as soon as we service the the card, 'cause we service model. Credit union can I get the card number? Please for me to check? Yes, it's a. It's a gift card, OK? OK, I'm now loading it here in our system one moment please in your name is you are. I'm sorry for the delay, just said still getting the information. OK, uhm, here's something came up now this system and showing here that this card is Broadway, uh, nothing back from this card is showing 0 balance. 0. This action was made well actually. First principle, initial funds was $50 in the first transaction made was at Target. Uh, it was made last or on a was this? Let me check the date. December 27, 2018. That was the first transaction and the balance went down to a $38.28 second transaction made this month. Uh oh, actually today January 20th, 2019 for $10 and five cents at Dillard's, says here and the balance went down to $28.23 in that balance was. Was this was used at? Mercy, she didn't do that, so someone must have this. I've had the card all day. She didn't go to Dillard's today. That is so weird. How about this? Yeah. An this was made at Midland, TX. Showing here OK for going to check the what was the amount again to $28.33. So using that balance went down to 0. When was that made at James Avery? What day? Today Directions today. James Avery Are you sure it's discard 'cause? Yeah. Yeah, we didn't do him, that's why I'm trying to tell you, Samantha. Today Yeah, well, it's stolen. They got the number stolen. I'm holding the card Oregon, we didn't use it. Um, I'm just giving you is, uh, the whatever information that we have. Hello, Are you sure was 2020? Yeah, January 20th 2019. And 1919 OK this is 20. 2019 And Yeah, you said today he said today. I'm sorry. Siri said OK. Oh, I'm sorry about that. But let me yeah, so you change my bad biologies. OK, I was fine. We've been here. OK, then she did use it last time. Like that's weird. I'm holding the card. OK, that makes sense. She just didn't know she already used it last year. That makes sense. I'm sorry about. That man, Oh no, you're fine. I was like I am so confused. Now that I really yeah, I said again, uh, two transactions made last year. 22,019 and about 10,000 year old. Now so OK, thank you. Do you have any car undercards aside from this? No, no, no. There are other ones, yeah. OK. Bye."
#         }
#       ],
#       "SegmentResults": [
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 36500000,
#           "Duration": 38500000,
#           "OffsetInSeconds": 3.65,
#           "DurationInSeconds": 3.85,
#           "NBest": [
#             {
#               "Confidence": 0.780086637,
#               "Lexical": "they will call good holder services my name is jimmy only had the card number please",
#               "ITN": "they will call good holder services my name is jimmy only had the card number please",
#               "MaskedITN": "they will call good holder services my name is jimmy only had the card number please",
#               "Display": "They will call good Holder services. My name is Jimmy only had the card number please.",
#               "Sentiment": {
#                 "Negative": 0.0,
#                 "Neutral": 0.0,
#                 "Positive": 1.0
#               },
#               "Words": [
#                 {
#                   "Word": "they",
#                   "Offset": 36500000,
#                   "Duration": 1800000,
#                   "OffsetInSeconds": 3.65,
#                   "DurationInSeconds": 0.18,
#                   "Confidence": 0.91631
#                 },
#                 {
#                   "Word": "will",
#                   "Offset": 38300000,
#                   "Duration": 1500000,
#                   "OffsetInSeconds": 3.83,
#                   "DurationInSeconds": 0.15,
#                   "Confidence": 0.803557
#                 },
#                 {
#                   "Word": "call",
#                   "Offset": 39800000,
#                   "Duration": 2300000,
#                   "OffsetInSeconds": 3.98,
#                   "DurationInSeconds": 0.23,
#                   "Confidence": 0.849724
#                 },
#                 {
#                   "Word": "good",
#                   "Offset": 42100000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 4.21,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.958122
#                 },
#                 {
#                   "Word": "holder",
#                   "Offset": 43700000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 4.37,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.757125
#                 },
#                 {
#                   "Word": "services",
#                   "Offset": 46300000,
#                   "Duration": 4800000,
#                   "OffsetInSeconds": 4.63,
#                   "DurationInSeconds": 0.48,
#                   "Confidence": 0.968961
#                 },
#                 {
#                   "Word": "my",
#                   "Offset": 51100000,
#                   "Duration": 1400000,
#                   "OffsetInSeconds": 5.11,
#                   "DurationInSeconds": 0.14,
#                   "Confidence": 0.951298
#                 },
#                 {
#                   "Word": "name",
#                   "Offset": 52500000,
#                   "Duration": 1500000,
#                   "OffsetInSeconds": 5.25,
#                   "DurationInSeconds": 0.15,
#                   "Confidence": 0.971567
#                 },
#                 {
#                   "Word": "is",
#                   "Offset": 54000000,
#                   "Duration": 1200000,
#                   "OffsetInSeconds": 5.4,
#                   "DurationInSeconds": 0.12,
#                   "Confidence": 0.952004
#                 },
#                 {
#                   "Word": "jimmy",
#                   "Offset": 55200000,
#                   "Duration": 2800000,
#                   "OffsetInSeconds": 5.52,
#                   "DurationInSeconds": 0.28,
#                   "Confidence": 0.949641
#                 },
#                 {
#                   "Word": "only",
#                   "Offset": 58000000,
#                   "Duration": 2000000,
#                   "OffsetInSeconds": 5.8,
#                   "DurationInSeconds": 0.2,
#                   "Confidence": 0.921505
#                 },
#                 {
#                   "Word": "had",
#                   "Offset": 60000000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 6.0,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.923827
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 61700000,
#                   "Duration": 1000000,
#                   "OffsetInSeconds": 6.17,
#                   "DurationInSeconds": 0.1,
#                   "Confidence": 0.687347
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 62700000,
#                   "Duration": 4000000,
#                   "OffsetInSeconds": 6.27,
#                   "DurationInSeconds": 0.4,
#                   "Confidence": 0.973833
#                 },
#                 {
#                   "Word": "number",
#                   "Offset": 66700000,
#                   "Duration": 2800000,
#                   "OffsetInSeconds": 6.67,
#                   "DurationInSeconds": 0.28,
#                   "Confidence": 0.985657
#                 },
#                 {
#                   "Word": "please",
#                   "Offset": 69500000,
#                   "Duration": 5500000,
#                   "OffsetInSeconds": 6.95,
#                   "DurationInSeconds": 0.55,
#                   "Confidence": 0.99358
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 83700000,
#           "Duration": 126600000,
#           "OffsetInSeconds": 8.37,
#           "DurationInSeconds": 12.66,
#           "NBest": [
#             {
#               "Confidence": 0.922905564,
#               "Lexical": "yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so",
#               "ITN": "yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so",
#               "MaskedITN": "yes but first let me ask my daughter receive this gift card for christmas southwest bank gift card and we're trying to get a balance on it keeps asking for a pin with course she doesn't have a pen so",
#               "Display": "Yes, but first let me ask my daughter receive this gift card for Christmas. Southwest Bank gift card and we're trying to get a balance on it. Keeps asking for a pin with course she doesn't have a pen, so.",
#               "Sentiment": {
#                 "Negative": 0.999532,
#                 "Neutral": 0.0,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "yes",
#                   "Offset": 83700000,
#                   "Duration": 3700000,
#                   "OffsetInSeconds": 8.37,
#                   "DurationInSeconds": 0.37,
#                   "Confidence": 0.966876
#                 },
#                 {
#                   "Word": "but",
#                   "Offset": 87400000,
#                   "Duration": 2200000,
#                   "OffsetInSeconds": 8.74,
#                   "DurationInSeconds": 0.22,
#                   "Confidence": 0.731385
#                 },
#                 {
#                   "Word": "first",
#                   "Offset": 89600000,
#                   "Duration": 2900000,
#                   "OffsetInSeconds": 8.96,
#                   "DurationInSeconds": 0.29,
#                   "Confidence": 0.967292
#                 },
#                 {
#                   "Word": "let",
#                   "Offset": 92500000,
#                   "Duration": 1100000,
#                   "OffsetInSeconds": 9.25,
#                   "DurationInSeconds": 0.11,
#                   "Confidence": 0.9853
#                 },
#                 {
#                   "Word": "me",
#                   "Offset": 93600000,
#                   "Duration": 1000000,
#                   "OffsetInSeconds": 9.36,
#                   "DurationInSeconds": 0.1,
#                   "Confidence": 0.902764
#                 },
#                 {
#                   "Word": "ask",
#                   "Offset": 94600000,
#                   "Duration": 3000000,
#                   "OffsetInSeconds": 9.46,
#                   "DurationInSeconds": 0.3,
#                   "Confidence": 0.98925
#                 },
#                 {
#                   "Word": "my",
#                   "Offset": 97600000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 9.76,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.926288
#                 },
#                 {
#                   "Word": "daughter",
#                   "Offset": 99200000,
#                   "Duration": 3200000,
#                   "OffsetInSeconds": 9.92,
#                   "DurationInSeconds": 0.32,
#                   "Confidence": 0.97817
#                 },
#                 {
#                   "Word": "receive",
#                   "Offset": 102400000,
#                   "Duration": 4800000,
#                   "OffsetInSeconds": 10.24,
#                   "DurationInSeconds": 0.48,
#                   "Confidence": 0.975293
#                 },
#                 {
#                   "Word": "this",
#                   "Offset": 107200000,
#                   "Duration": 2200000,
#                   "OffsetInSeconds": 10.72,
#                   "DurationInSeconds": 0.22,
#                   "Confidence": 0.964716
#                 },
#                 {
#                   "Word": "gift",
#                   "Offset": 109400000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 10.94,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.985725
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 112000000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 11.2,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.97678
#                 },
#                 {
#                   "Word": "for",
#                   "Offset": 114600000,
#                   "Duration": 1400000,
#                   "OffsetInSeconds": 11.46,
#                   "DurationInSeconds": 0.14,
#                   "Confidence": 0.959422
#                 },
#                 {
#                   "Word": "christmas",
#                   "Offset": 116000000,
#                   "Duration": 5900000,
#                   "OffsetInSeconds": 11.6,
#                   "DurationInSeconds": 0.59,
#                   "Confidence": 0.995595
#                 },
#                 {
#                   "Word": "southwest",
#                   "Offset": 121900000,
#                   "Duration": 5500000,
#                   "OffsetInSeconds": 12.19,
#                   "DurationInSeconds": 0.55,
#                   "Confidence": 0.910037
#                 },
#                 {
#                   "Word": "bank",
#                   "Offset": 127400000,
#                   "Duration": 2300000,
#                   "OffsetInSeconds": 12.74,
#                   "DurationInSeconds": 0.23,
#                   "Confidence": 0.940531
#                 },
#                 {
#                   "Word": "gift",
#                   "Offset": 129700000,
#                   "Duration": 2500000,
#                   "OffsetInSeconds": 12.97,
#                   "DurationInSeconds": 0.25,
#                   "Confidence": 0.977282
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 132200000,
#                   "Duration": 6000000,
#                   "OffsetInSeconds": 13.22,
#                   "DurationInSeconds": 0.6,
#                   "Confidence": 0.991872
#                 },
#                 {
#                   "Word": "and",
#                   "Offset": 139000000,
#                   "Duration": 3800000,
#                   "OffsetInSeconds": 13.9,
#                   "DurationInSeconds": 0.38,
#                   "Confidence": 0.887017
#                 },
#                 {
#                   "Word": "we're",
#                   "Offset": 142800000,
#                   "Duration": 1400000,
#                   "OffsetInSeconds": 14.28,
#                   "DurationInSeconds": 0.14,
#                   "Confidence": 0.844312
#                 },
#                 {
#                   "Word": "trying",
#                   "Offset": 144200000,
#                   "Duration": 2900000,
#                   "OffsetInSeconds": 14.42,
#                   "DurationInSeconds": 0.29,
#                   "Confidence": 0.988977
#                 },
#                 {
#                   "Word": "to",
#                   "Offset": 147100000,
#                   "Duration": 700000,
#                   "OffsetInSeconds": 14.71,
#                   "DurationInSeconds": 0.07,
#                   "Confidence": 0.880221
#                 },
#                 {
#                   "Word": "get",
#                   "Offset": 147800000,
#                   "Duration": 2800000,
#                   "OffsetInSeconds": 14.78,
#                   "DurationInSeconds": 0.28,
#                   "Confidence": 0.984806
#                 },
#                 {
#                   "Word": "a",
#                   "Offset": 150600000,
#                   "Duration": 800000,
#                   "OffsetInSeconds": 15.06,
#                   "DurationInSeconds": 0.08,
#                   "Confidence": 0.971421
#                 },
#                 {
#                   "Word": "balance",
#                   "Offset": 151400000,
#                   "Duration": 10300000,
#                   "OffsetInSeconds": 15.14,
#                   "DurationInSeconds": 1.03,
#                   "Confidence": 0.993537
#                 },
#                 {
#                   "Word": "on",
#                   "Offset": 161900000,
#                   "Duration": 3600000,
#                   "OffsetInSeconds": 16.19,
#                   "DurationInSeconds": 0.36,
#                   "Confidence": 0.987268
#                 },
#                 {
#                   "Word": "it",
#                   "Offset": 165500000,
#                   "Duration": 2700000,
#                   "OffsetInSeconds": 16.55,
#                   "DurationInSeconds": 0.27,
#                   "Confidence": 0.659474
#                 },
#                 {
#                   "Word": "keeps",
#                   "Offset": 168200000,
#                   "Duration": 3000000,
#                   "OffsetInSeconds": 16.82,
#                   "DurationInSeconds": 0.3,
#                   "Confidence": 0.95688
#                 },
#                 {
#                   "Word": "asking",
#                   "Offset": 171200000,
#                   "Duration": 4100000,
#                   "OffsetInSeconds": 17.12,
#                   "DurationInSeconds": 0.41,
#                   "Confidence": 0.988451
#                 },
#                 {
#                   "Word": "for",
#                   "Offset": 175300000,
#                   "Duration": 1500000,
#                   "OffsetInSeconds": 17.53,
#                   "DurationInSeconds": 0.15,
#                   "Confidence": 0.936782
#                 },
#                 {
#                   "Word": "a",
#                   "Offset": 176800000,
#                   "Duration": 800000,
#                   "OffsetInSeconds": 17.68,
#                   "DurationInSeconds": 0.08,
#                   "Confidence": 0.978203
#                 },
#                 {
#                   "Word": "pin",
#                   "Offset": 177600000,
#                   "Duration": 4200000,
#                   "OffsetInSeconds": 17.76,
#                   "DurationInSeconds": 0.42,
#                   "Confidence": 0.97353
#                 },
#                 {
#                   "Word": "with",
#                   "Offset": 181800000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 18.18,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.907598
#                 },
#                 {
#                   "Word": "course",
#                   "Offset": 183500000,
#                   "Duration": 5500000,
#                   "OffsetInSeconds": 18.35,
#                   "DurationInSeconds": 0.55,
#                   "Confidence": 0.954158
#                 },
#                 {
#                   "Word": "she",
#                   "Offset": 189000000,
#                   "Duration": 3000000,
#                   "OffsetInSeconds": 18.9,
#                   "DurationInSeconds": 0.3,
#                   "Confidence": 0.977877
#                 },
#                 {
#                   "Word": "doesn't",
#                   "Offset": 192000000,
#                   "Duration": 3600000,
#                   "OffsetInSeconds": 19.2,
#                   "DurationInSeconds": 0.36,
#                   "Confidence": 0.984587
#                 },
#                 {
#                   "Word": "have",
#                   "Offset": 195600000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 19.56,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.97413
#                 },
#                 {
#                   "Word": "a",
#                   "Offset": 198200000,
#                   "Duration": 1000000,
#                   "OffsetInSeconds": 19.82,
#                   "DurationInSeconds": 0.1,
#                   "Confidence": 0.975284
#                 },
#                 {
#                   "Word": "pen",
#                   "Offset": 199200000,
#                   "Duration": 4800000,
#                   "OffsetInSeconds": 19.92,
#                   "DurationInSeconds": 0.48,
#                   "Confidence": 0.960164
#                 },
#                 {
#                   "Word": "so",
#                   "Offset": 204000000,
#                   "Duration": 6300000,
#                   "OffsetInSeconds": 20.4,
#                   "DurationInSeconds": 0.63,
#                   "Confidence": 0.987719
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 215800000,
#           "Duration": 18300000,
#           "OffsetInSeconds": 21.58,
#           "DurationInSeconds": 1.83,
#           "NBest": [
#             {
#               "Confidence": 0.847099,
#               "Lexical": "can you switch the balances",
#               "ITN": "can you switch the balances",
#               "MaskedITN": "can you switch the balances",
#               "Display": "Can you switch the balances?",
#               "Sentiment": {
#                 "Negative": 0.193801,
#                 "Neutral": 0.806182,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "can",
#                   "Offset": 215800000,
#                   "Duration": 2900000,
#                   "OffsetInSeconds": 21.58,
#                   "DurationInSeconds": 0.29,
#                   "Confidence": 0.974323
#                 },
#                 {
#                   "Word": "you",
#                   "Offset": 218700000,
#                   "Duration": 1300000,
#                   "OffsetInSeconds": 21.87,
#                   "DurationInSeconds": 0.13,
#                   "Confidence": 0.980541
#                 },
#                 {
#                   "Word": "switch",
#                   "Offset": 220000000,
#                   "Duration": 2500000,
#                   "OffsetInSeconds": 22.0,
#                   "DurationInSeconds": 0.25,
#                   "Confidence": 0.806996
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 222500000,
#                   "Duration": 1100000,
#                   "OffsetInSeconds": 22.25,
#                   "DurationInSeconds": 0.11,
#                   "Confidence": 0.873575
#                 },
#                 {
#                   "Word": "balances",
#                   "Offset": 223600000,
#                   "Duration": 10500000,
#                   "OffsetInSeconds": 22.36,
#                   "DurationInSeconds": 1.05,
#                   "Confidence": 0.98902
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 240900000,
#           "Duration": 59700000,
#           "OffsetInSeconds": 24.09,
#           "DurationInSeconds": 5.97,
#           "NBest": [
#             {
#               "Confidence": 0.847099,
#               "Lexical": "i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model",
#               "ITN": "i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model",
#               "MaskedITN": "i'm sorry about it but uh if you want to check the balance as soon as we service the the card 'cause we service model",
#               "Display": "I'm sorry about it. But uh, if you want to check the balance as soon as we service the the card, 'cause we service model.",
#               "Sentiment": {
#                 "Negative": 0.165329,
#                 "Neutral": 0.834648,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "i'm",
#                   "Offset": 240900000,
#                   "Duration": 3400000,
#                   "OffsetInSeconds": 24.09,
#                   "DurationInSeconds": 0.34,
#                   "Confidence": 0.907376
#                 },
#                 {
#                   "Word": "sorry",
#                   "Offset": 244300000,
#                   "Duration": 1900000,
#                   "OffsetInSeconds": 24.43,
#                   "DurationInSeconds": 0.19,
#                   "Confidence": 0.931071
#                 },
#                 {
#                   "Word": "about",
#                   "Offset": 246200000,
#                   "Duration": 2300000,
#                   "OffsetInSeconds": 24.62,
#                   "DurationInSeconds": 0.23,
#                   "Confidence": 0.961556
#                 },
#                 {
#                   "Word": "it",
#                   "Offset": 248500000,
#                   "Duration": 1100000,
#                   "OffsetInSeconds": 24.85,
#                   "DurationInSeconds": 0.11,
#                   "Confidence": 0.955459
#                 },
#                 {
#                   "Word": "but",
#                   "Offset": 249600000,
#                   "Duration": 2300000,
#                   "OffsetInSeconds": 24.96,
#                   "DurationInSeconds": 0.23,
#                   "Confidence": 0.988847
#                 },
#                 {
#                   "Word": "uh",
#                   "Offset": 252100000,
#                   "Duration": 3800000,
#                   "OffsetInSeconds": 25.21,
#                   "DurationInSeconds": 0.38,
#                   "Confidence": 0.979274
#                 },
#                 {
#                   "Word": "if",
#                   "Offset": 255900000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 25.59,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.884578
#                 },
#                 {
#                   "Word": "you",
#                   "Offset": 257600000,
#                   "Duration": 900000,
#                   "OffsetInSeconds": 25.76,
#                   "DurationInSeconds": 0.09,
#                   "Confidence": 0.978265
#                 },
#                 {
#                   "Word": "want",
#                   "Offset": 258500000,
#                   "Duration": 1400000,
#                   "OffsetInSeconds": 25.85,
#                   "DurationInSeconds": 0.14,
#                   "Confidence": 0.967638
#                 },
#                 {
#                   "Word": "to",
#                   "Offset": 259900000,
#                   "Duration": 800000,
#                   "OffsetInSeconds": 25.99,
#                   "DurationInSeconds": 0.08,
#                   "Confidence": 0.400911
#                 },
#                 {
#                   "Word": "check",
#                   "Offset": 260700000,
#                   "Duration": 2000000,
#                   "OffsetInSeconds": 26.07,
#                   "DurationInSeconds": 0.2,
#                   "Confidence": 0.9743
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 262700000,
#                   "Duration": 1200000,
#                   "OffsetInSeconds": 26.27,
#                   "DurationInSeconds": 0.12,
#                   "Confidence": 0.916953
#                 },
#                 {
#                   "Word": "balance",
#                   "Offset": 263900000,
#                   "Duration": 5000000,
#                   "OffsetInSeconds": 26.39,
#                   "DurationInSeconds": 0.5,
#                   "Confidence": 0.94055
#                 },
#                 {
#                   "Word": "as",
#                   "Offset": 268900000,
#                   "Duration": 1100000,
#                   "OffsetInSeconds": 26.89,
#                   "DurationInSeconds": 0.11,
#                   "Confidence": 0.741804
#                 },
#                 {
#                   "Word": "soon",
#                   "Offset": 270000000,
#                   "Duration": 1900000,
#                   "OffsetInSeconds": 27.0,
#                   "DurationInSeconds": 0.19,
#                   "Confidence": 0.985531
#                 },
#                 {
#                   "Word": "as",
#                   "Offset": 271900000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 27.19,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.983773
#                 },
#                 {
#                   "Word": "we",
#                   "Offset": 273500000,
#                   "Duration": 2200000,
#                   "OffsetInSeconds": 27.35,
#                   "DurationInSeconds": 0.22,
#                   "Confidence": 0.980633
#                 },
#                 {
#                   "Word": "service",
#                   "Offset": 275700000,
#                   "Duration": 3800000,
#                   "OffsetInSeconds": 27.57,
#                   "DurationInSeconds": 0.38,
#                   "Confidence": 0.863328
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 279500000,
#                   "Duration": 3800000,
#                   "OffsetInSeconds": 27.95,
#                   "DurationInSeconds": 0.38,
#                   "Confidence": 0.867148
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 283300000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 28.33,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.88208
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 284900000,
#                   "Duration": 5800000,
#                   "OffsetInSeconds": 28.49,
#                   "DurationInSeconds": 0.58,
#                   "Confidence": 0.979923
#                 },
#                 {
#                   "Word": "'cause",
#                   "Offset": 290700000,
#                   "Duration": 2400000,
#                   "OffsetInSeconds": 29.07,
#                   "DurationInSeconds": 0.24,
#                   "Confidence": 0.920268
#                 },
#                 {
#                   "Word": "we",
#                   "Offset": 293100000,
#                   "Duration": 1000000,
#                   "OffsetInSeconds": 29.31,
#                   "DurationInSeconds": 0.1,
#                   "Confidence": 0.913274
#                 },
#                 {
#                   "Word": "service",
#                   "Offset": 294100000,
#                   "Duration": 3200000,
#                   "OffsetInSeconds": 29.41,
#                   "DurationInSeconds": 0.32,
#                   "Confidence": 0.934722
#                 },
#                 {
#                   "Word": "model",
#                   "Offset": 297300000,
#                   "Duration": 3300000,
#                   "OffsetInSeconds": 29.73,
#                   "DurationInSeconds": 0.33,
#                   "Confidence": 0.961283
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 317100000,
#           "Duration": 30600000,
#           "OffsetInSeconds": 31.71,
#           "DurationInSeconds": 3.06,
#           "NBest": [
#             {
#               "Confidence": 0.8778057,
#               "Lexical": "credit union can i get the card number please for me to check",
#               "ITN": "credit union can i get the card number please for me to check",
#               "MaskedITN": "credit union can i get the card number please for me to check",
#               "Display": "Credit union can I get the card number? Please for me to check?",
#               "Sentiment": {
#                 "Negative": 1.0,
#                 "Neutral": 0.0,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "credit",
#                   "Offset": 317100000,
#                   "Duration": 3500000,
#                   "OffsetInSeconds": 31.71,
#                   "DurationInSeconds": 0.35,
#                   "Confidence": 0.952136
#                 },
#                 {
#                   "Word": "union",
#                   "Offset": 320600000,
#                   "Duration": 3300000,
#                   "OffsetInSeconds": 32.06,
#                   "DurationInSeconds": 0.33,
#                   "Confidence": 0.976743
#                 },
#                 {
#                   "Word": "can",
#                   "Offset": 326000000,
#                   "Duration": 1900000,
#                   "OffsetInSeconds": 32.6,
#                   "DurationInSeconds": 0.19,
#                   "Confidence": 0.544784
#                 },
#                 {
#                   "Word": "i",
#                   "Offset": 327900000,
#                   "Duration": 400000,
#                   "OffsetInSeconds": 32.79,
#                   "DurationInSeconds": 0.04,
#                   "Confidence": 0.931711
#                 },
#                 {
#                   "Word": "get",
#                   "Offset": 328300000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 32.83,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.97499
#                 },
#                 {
#                   "Word": "the",
#                   "Offset": 330000000,
#                   "Duration": 900000,
#                   "OffsetInSeconds": 33.0,
#                   "DurationInSeconds": 0.09,
#                   "Confidence": 0.505417
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 330900000,
#                   "Duration": 3000000,
#                   "OffsetInSeconds": 33.09,
#                   "DurationInSeconds": 0.3,
#                   "Confidence": 0.959446
#                 },
#                 {
#                   "Word": "number",
#                   "Offset": 333900000,
#                   "Duration": 2400000,
#                   "OffsetInSeconds": 33.39,
#                   "DurationInSeconds": 0.24,
#                   "Confidence": 0.98268
#                 },
#                 {
#                   "Word": "please",
#                   "Offset": 336300000,
#                   "Duration": 3000000,
#                   "OffsetInSeconds": 33.63,
#                   "DurationInSeconds": 0.3,
#                   "Confidence": 0.945495
#                 },
#                 {
#                   "Word": "for",
#                   "Offset": 339300000,
#                   "Duration": 1800000,
#                   "OffsetInSeconds": 33.93,
#                   "DurationInSeconds": 0.18,
#                   "Confidence": 0.97598
#                 },
#                 {
#                   "Word": "me",
#                   "Offset": 341100000,
#                   "Duration": 800000,
#                   "OffsetInSeconds": 34.11,
#                   "DurationInSeconds": 0.08,
#                   "Confidence": 0.635538
#                 },
#                 {
#                   "Word": "to",
#                   "Offset": 341900000,
#                   "Duration": 1200000,
#                   "OffsetInSeconds": 34.19,
#                   "DurationInSeconds": 0.12,
#                   "Confidence": 0.784154
#                 },
#                 {
#                   "Word": "check",
#                   "Offset": 343100000,
#                   "Duration": 4600000,
#                   "OffsetInSeconds": 34.31,
#                   "DurationInSeconds": 0.46,
#                   "Confidence": 0.991925
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 349100000,
#           "Duration": 23200000,
#           "OffsetInSeconds": 34.91,
#           "DurationInSeconds": 2.32,
#           "NBest": [
#             {
#               "Confidence": 0.8778057,
#               "Lexical": "yes it's a it's a gift card OK",
#               "ITN": "yes it's a it's a gift card OK",
#               "MaskedITN": "yes it's a it's a gift card ok",
#               "Display": "Yes, it's a. It's a gift card, OK?",
#               "Sentiment": {
#                 "Negative": 0.126604,
#                 "Neutral": 0.873347,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "yes",
#                   "Offset": 349100000,
#                   "Duration": 4000000,
#                   "OffsetInSeconds": 34.91,
#                   "DurationInSeconds": 0.4,
#                   "Confidence": 0.943862
#                 },
#                 {
#                   "Word": "it's",
#                   "Offset": 353100000,
#                   "Duration": 1800000,
#                   "OffsetInSeconds": 35.31,
#                   "DurationInSeconds": 0.18,
#                   "Confidence": 0.898901
#                 },
#                 {
#                   "Word": "a",
#                   "Offset": 354900000,
#                   "Duration": 1200000,
#                   "OffsetInSeconds": 35.49,
#                   "DurationInSeconds": 0.12,
#                   "Confidence": 0.894313
#                 },
#                 {
#                   "Word": "it's",
#                   "Offset": 356100000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 35.61,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.979245
#                 },
#                 {
#                   "Word": "a",
#                   "Offset": 358700000,
#                   "Duration": 800000,
#                   "OffsetInSeconds": 35.87,
#                   "DurationInSeconds": 0.08,
#                   "Confidence": 0.962168
#                 },
#                 {
#                   "Word": "gift",
#                   "Offset": 359500000,
#                   "Duration": 2800000,
#                   "OffsetInSeconds": 35.95,
#                   "DurationInSeconds": 0.28,
#                   "Confidence": 0.982427
#                 },
#                 {
#                   "Word": "card",
#                   "Offset": 362300000,
#                   "Duration": 3700000,
#                   "OffsetInSeconds": 36.23,
#                   "DurationInSeconds": 0.37,
#                   "Confidence": 0.994351
#                 },
#                 {
#                   "Word": "OK",
#                   "Offset": 366200000,
#                   "Duration": 6100000,
#                   "OffsetInSeconds": 36.62,
#                   "DurationInSeconds": 0.61,
#                   "Confidence": 0.985834
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 386800000,
#           "Duration": 63800000,
#           "OffsetInSeconds": 38.68,
#           "DurationInSeconds": 6.38,
#           "NBest": [
#             {
#               "Confidence": 0.8438503,
#               "Lexical": "OK i'm now loading it here in our system one moment please in your name is you are",
#               "ITN": "OK i'm now loading it here in our system one moment please in your name is you are",
#               "MaskedITN": "ok i'm now loading it here in our system one moment please in your name is you are",
#               "Display": "OK, I'm now loading it here in our system one moment please in your name is you are.",
#               "Sentiment": {
#                 "Negative": 0.141965,
#                 "Neutral": 0.85799,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "OK",
#                   "Offset": 386800000,
# ...
#                   "DurationInSeconds": 0.43,
#                   "Confidence": 0.978851
#                 },
#                 {
#                   "Word": "uh",
#                   "Offset": 2668000000,
#                   "Duration": 3300000,
#                   "OffsetInSeconds": 266.8,
#                   "DurationInSeconds": 0.33,
#                   "Confidence": 0.790811
#                 },
#                 {
#                   "Word": "two",
#                   "Offset": 2671300000,
#                   "Duration": 1400000,
#                   "OffsetInSeconds": 267.13,
#                   "DurationInSeconds": 0.14,
#                   "Confidence": 0.815722
#                 },
#                 {
#                   "Word": "transactions",
#                   "Offset": 2672700000,
#                   "Duration": 8000000,
#                   "OffsetInSeconds": 267.27,
#                   "DurationInSeconds": 0.8,
#                   "Confidence": 0.968749
#                 },
#                 {
#                   "Word": "made",
#                   "Offset": 2680700000,
#                   "Duration": 4200000,
#                   "OffsetInSeconds": 268.07,
#                   "DurationInSeconds": 0.42,
#                   "Confidence": 0.980355
#                 },
#                 {
#                   "Word": "last",
#                   "Offset": 2684900000,
#                   "Duration": 3300000,
#                   "OffsetInSeconds": 268.49,
#                   "DurationInSeconds": 0.33,
#                   "Confidence": 0.981472
#                 },
#                 {
#                   "Word": "year",
#                   "Offset": 2688200000,
#                   "Duration": 3100000,
#                   "OffsetInSeconds": 268.82,
#                   "DurationInSeconds": 0.31,
#                   "Confidence": 0.984506
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 2707300000,
#           "Duration": 37200000,
#           "OffsetInSeconds": 270.73,
#           "DurationInSeconds": 3.72,
#           "NBest": [
#             {
#               "Confidence": 0.8469867,
#               "Lexical": "twenty two thousand nineteen and about ten thousand year old",
#               "ITN": "22019 and about 10000 year old",
#               "MaskedITN": "22019 and about 10000 year old",
#               "Display": "22,019 and about 10,000 year old.",
#               "Sentiment": {
#                 "Negative": 0.17136,
#                 "Neutral": 0.828626,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "twenty",
#                   "Offset": 2707300000,
#                   "Duration": 3400000,
#                   "OffsetInSeconds": 270.73,
#                   "DurationInSeconds": 0.34,
#                   "Confidence": 0.86526
#                 },
#                 {
#                   "Word": "two",
#                   "Offset": 2710700000,
#                   "Duration": 1800000,
#                   "OffsetInSeconds": 271.07,
#                   "DurationInSeconds": 0.18,
#                   "Confidence": 0.868109
#                 },
#                 {
#                   "Word": "thousand",
#                   "Offset": 2712500000,
#                   "Duration": 4000000,
#                   "OffsetInSeconds": 271.25,
#                   "DurationInSeconds": 0.4,
#                   "Confidence": 0.991141
#                 },
#                 {
#                   "Word": "nineteen",
#                   "Offset": 2716500000,
#                   "Duration": 8800000,
#                   "OffsetInSeconds": 271.65,
#                   "DurationInSeconds": 0.88,
#                   "Confidence": 0.994623
#                 },
#                 {
#                   "Word": "and",
#                   "Offset": 2728200000,
#                   "Duration": 3500000,
#                   "OffsetInSeconds": 272.82,
#                   "DurationInSeconds": 0.35,
#                   "Confidence": 0.931962
#                 },
#                 {
#                   "Word": "about",
#                   "Offset": 2731700000,
#                   "Duration": 2600000,
#                   "OffsetInSeconds": 273.17,
#                   "DurationInSeconds": 0.26,
#                   "Confidence": 0.896901
#                 },
#                 {
#                   "Word": "ten",
#                   "Offset": 2734300000,
#                   "Duration": 2000000,
#                   "OffsetInSeconds": 273.43,
#                   "DurationInSeconds": 0.2,
#                   "Confidence": 0.648173
#                 },
#                 {
#                   "Word": "thousand",
#                   "Offset": 2736300000,
#                   "Duration": 4400000,
#                   "OffsetInSeconds": 273.63,
#                   "DurationInSeconds": 0.44,
#                   "Confidence": 0.954474
#                 },
#                 {
#                   "Word": "year",
#                   "Offset": 2740700000,
#                   "Duration": 2200000,
#                   "OffsetInSeconds": 274.07,
#                   "DurationInSeconds": 0.22,
#                   "Confidence": 0.903698
#                 },
#                 {
#                   "Word": "old",
#                   "Offset": 2742900000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 274.29,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.987325
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 2744500000,
#           "Duration": 29200000,
#           "OffsetInSeconds": 274.45,
#           "DurationInSeconds": 2.92,
#           "NBest": [
#             {
#               "Confidence": 0.8469867,
#               "Lexical": "now so OK thank you",
#               "ITN": "now so OK thank you",
#               "MaskedITN": "now so ok thank you",
#               "Display": "Now so OK, thank you.",
#               "Sentiment": {
#                 "Negative": 0.0,
#                 "Neutral": 0.0,
#                 "Positive": 1.0
#               },
#               "Words": [
#                 {
#                   "Word": "now",
#                   "Offset": 2744500000,
#                   "Duration": 4600000,
#                   "OffsetInSeconds": 274.45,
#                   "DurationInSeconds": 0.46,
#                   "Confidence": 0.983755
#                 },
#                 {
#                   "Word": "so",
#                   "Offset": 2749300000,
#                   "Duration": 4000000,
#                   "OffsetInSeconds": 274.93,
#                   "DurationInSeconds": 0.4,
#                   "Confidence": 0.942321
#                 },
#                 {
#                   "Word": "OK",
#                   "Offset": 2754700000,
#                   "Duration": 7700000,
#                   "OffsetInSeconds": 275.47,
#                   "DurationInSeconds": 0.77,
#                   "Confidence": 0.987758
#                 },
#                 {
#                   "Word": "thank",
#                   "Offset": 2762600000,
#                   "Duration": 5300000,
#                   "OffsetInSeconds": 276.26,
#                   "DurationInSeconds": 0.53,
#                   "Confidence": 0.992049
#                 },
#                 {
#                   "Word": "you",
#                   "Offset": 2767900000,
#                   "Duration": 5800000,
#                   "OffsetInSeconds": 276.79,
#                   "DurationInSeconds": 0.58,
#                   "Confidence": 0.994294
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 2777500000,
#           "Duration": 24200000,
#           "OffsetInSeconds": 277.75,
#           "DurationInSeconds": 2.42,
#           "NBest": [
#             {
#               "Confidence": 0.8469867,
#               "Lexical": "do you have any car undercards aside from this",
#               "ITN": "do you have any car undercards aside from this",
#               "MaskedITN": "do you have any car undercards aside from this",
#               "Display": "Do you have any car undercards aside from this?",
#               "Sentiment": {
#                 "Negative": 0.185465,
#                 "Neutral": 0.814511,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "do",
#                   "Offset": 2777500000,
#                   "Duration": 2300000,
#                   "OffsetInSeconds": 277.75,
#                   "DurationInSeconds": 0.23,
#                   "Confidence": 0.688052
#                 },
#                 {
#                   "Word": "you",
#                   "Offset": 2779800000,
#                   "Duration": 600000,
#                   "OffsetInSeconds": 277.98,
#                   "DurationInSeconds": 0.06,
#                   "Confidence": 0.943639
#                 },
#                 {
#                   "Word": "have",
#                   "Offset": 2780400000,
#                   "Duration": 1500000,
#                   "OffsetInSeconds": 278.04,
#                   "DurationInSeconds": 0.15,
#                   "Confidence": 0.933231
#                 },
#                 {
#                   "Word": "any",
#                   "Offset": 2781900000,
#                   "Duration": 2000000,
#                   "OffsetInSeconds": 278.19,
#                   "DurationInSeconds": 0.2,
#                   "Confidence": 0.933061
#                 },
#                 {
#                   "Word": "car",
#                   "Offset": 2783900000,
#                   "Duration": 3400000,
#                   "OffsetInSeconds": 278.39,
#                   "DurationInSeconds": 0.34,
#                   "Confidence": 0.915883
#                 },
#                 {
#                   "Word": "undercards",
#                   "Offset": 2787300000,
#                   "Duration": 5600000,
#                   "OffsetInSeconds": 278.73,
#                   "DurationInSeconds": 0.56,
#                   "Confidence": 0.75935
#                 },
#                 {
#                   "Word": "aside",
#                   "Offset": 2792900000,
#                   "Duration": 2500000,
#                   "OffsetInSeconds": 279.29,
#                   "DurationInSeconds": 0.25,
#                   "Confidence": 0.705109
#                 },
#                 {
#                   "Word": "from",
#                   "Offset": 2795400000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 279.54,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.980633
#                 },
#                 {
#                   "Word": "this",
#                   "Offset": 2797100000,
#                   "Duration": 4600000,
#                   "OffsetInSeconds": 279.71,
#                   "DurationInSeconds": 0.46,
#                   "Confidence": 0.986216
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 2809600000,
#           "Duration": 25500000,
#           "OffsetInSeconds": 280.96,
#           "DurationInSeconds": 2.55,
#           "NBest": [
#             {
#               "Confidence": 0.8469867,
#               "Lexical": "no no no there are other ones yeah",
#               "ITN": "no no no there are other ones yeah",
#               "MaskedITN": "no no no there are other ones yeah",
#               "Display": "No, no, no. There are other ones, yeah.",
#               "Sentiment": {
#                 "Negative": 0.14846,
#                 "Neutral": 0.851514,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "no",
#                   "Offset": 2809600000,
#                   "Duration": 2800000,
#                   "OffsetInSeconds": 280.96,
#                   "DurationInSeconds": 0.28,
#                   "Confidence": 0.860187
#                 },
#                 {
#                   "Word": "no",
#                   "Offset": 2812400000,
#                   "Duration": 1700000,
#                   "OffsetInSeconds": 281.24,
#                   "DurationInSeconds": 0.17,
#                   "Confidence": 0.981253
#                 },
#                 {
#                   "Word": "no",
#                   "Offset": 2814100000,
#                   "Duration": 4000000,
#                   "OffsetInSeconds": 281.41,
#                   "DurationInSeconds": 0.4,
#                   "Confidence": 0.991055
#                 },
#                 {
#                   "Word": "there",
#                   "Offset": 2818400000,
#                   "Duration": 2100000,
#                   "OffsetInSeconds": 281.84,
#                   "DurationInSeconds": 0.21,
#                   "Confidence": 0.593303
#                 },
#                 {
#                   "Word": "are",
#                   "Offset": 2820500000,
#                   "Duration": 1600000,
#                   "OffsetInSeconds": 282.05,
#                   "DurationInSeconds": 0.16,
#                   "Confidence": 0.961326
#                 },
#                 {
#                   "Word": "other",
#                   "Offset": 2822100000,
#                   "Duration": 2400000,
#                   "OffsetInSeconds": 282.21,
#                   "DurationInSeconds": 0.24,
#                   "Confidence": 0.978128
#                 },
#                 {
#                   "Word": "ones",
#                   "Offset": 2824500000,
#                   "Duration": 4600000,
#                   "OffsetInSeconds": 282.45,
#                   "DurationInSeconds": 0.46,
#                   "Confidence": 0.977808
#                 },
#                 {
#                   "Word": "yeah",
#                   "Offset": 2829700000,
#                   "Duration": 5400000,
#                   "OffsetInSeconds": 282.97,
#                   "DurationInSeconds": 0.54,
#                   "Confidence": 0.963212
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "1",
#           "Offset": 2863900000,
#           "Duration": 6100000,
#           "OffsetInSeconds": 286.39,
#           "DurationInSeconds": 0.61,
#           "NBest": [
#             {
#               "Confidence": 0.3113904,
#               "Lexical": "OK",
#               "ITN": "OK",
#               "MaskedITN": "ok",
#               "Display": "OK.",
#               "Sentiment": {
#                 "Negative": 0.128167,
#                 "Neutral": 0.871816,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "OK",
#                   "Offset": 2863900000,
#                   "Duration": 6100000,
#                   "OffsetInSeconds": 286.39,
#                   "DurationInSeconds": 0.61,
#                   "Confidence": 0.843836
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "RecognitionStatus": "Success",
#           "ChannelNumber": null,
#           "SpeakerId": "2",
#           "Offset": 2877100000,
#           "Duration": 3600000,
#           "OffsetInSeconds": 287.71,
#           "DurationInSeconds": 0.36,
#           "NBest": [
#             {
#               "Confidence": 0.426483065,
#               "Lexical": "bye",
#               "ITN": "bye",
#               "MaskedITN": "bye",
#               "Display": "Bye.",
#               "Sentiment": {
#                 "Negative": 0.133701,
#                 "Neutral": 0.866284,
#                 "Positive": 0.0
#               },
#               "Words": [
#                 {
#                   "Word": "bye",
#                   "Offset": 2877100000,
#                   "Duration": 3600000,
#                   "OffsetInSeconds": 287.71,
#                   "DurationInSeconds": 0.36,
#                   "Confidence": 0.886997
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
audioFileResults = pd.read_json(response1)['AudioFileResults']
speakers_timestamps = {}
speakers = []

for i in audioFileResults:
        
    seg_results = i['SegmentResults']
    
    #find the speakers
    for j in seg_results:
        if j['SpeakerId'] not in speakers:
            speakers.append(j['SpeakerId'])            
    print("Unique set of speakers :")
    print(speakers)
    print('\n')
    
    for speaker in speakers:
        speaker_dict = {'speakerId' : speaker}
        OffsetInSeconds = []
        EndTimeInSeconds = []
        for segmentResult in seg_results:
            if segmentResult['SpeakerId'] == speaker:
                
                OffsetInSeconds.append(segmentResult['OffsetInSeconds'])
                #compute end time
                endTime = (timedelta(seconds=segmentResult['OffsetInSeconds']) + \
                timedelta(seconds=segmentResult['DurationInSeconds'])).total_seconds()
                EndTimeInSeconds.append(endTime)
               
        speaker_dict['start_timestamps'] = OffsetInSeconds
        speaker_dict['end_timestamps'] = EndTimeInSeconds
        
        speakers_timestamps[speaker] = speaker_dict
    
    print(speakers_timestamps)
    print('\n')

#convert to json object
json_obj = json.dumps(speakers_timestamps, indent=4)

print("printing json object.....\n")
print(json_obj)

with open("audiotimestamp.json", "w") as outfile: 
    outfile.write(json_obj)
# Out:
# Unique set of speakers :
# ['1', '2']
#
#
# {'1': {'speakerId': '1', 'start_timestamps': [3.65, 24.09, 31.71, 38.68, 66.31, 84.51, 89.75, 99.66, 132.21, 150.93, 153.14, 160.23, 176.57, 178.65, 182.16, 208.55, 218.76, 226.84, 231.88, 240.84, 258.5, 264.33, 270.73, 277.75, 286.39], 'end_timestamps': [7.5, 30.06, 34.77, 45.06, 83.73, 85.09, 98.88, 130.82, 134.49, 151.65, 158.68, 171.38, 177.21, 179.51, 183.34, 212.55, 221.32, 228.08, 232.66, 245.0, 259.5, 269.13, 274.45, 280.17, 287.0]}, '2': {'speakerId': '2', 'start_timestamps': [8.37, 21.58, 34.91, 134.49, 142.58, 147.22, 151.65, 172.82, 184.09, 186.91, 189.08, 197.02, 199.38, 214.4, 221.61, 228.36, 235.29, 238.69, 245.63, 259.5, 274.45, 280.96, 287.71], 'end_timestamps': [21.03, 23.41, 37.23, 140.93, 144.37, 148.75, 152.03, 176.21, 186.14, 187.24, 193.35, 197.59, 206.44, 217.73, 225.43, 231.52, 236.11, 239.31, 258.48, 262.73, 277.37, 283.51, 288.07]}}
#
#
# printing json object.....
#
# {
#     "1": {
#         "speakerId": "1",
#         "start_timestamps": [
#             3.65,
#             24.09,
#             31.71,
#             38.68,
#             66.31,
#             84.51,
#             89.75,
#             99.66,
#             132.21,
#             150.93,
#             153.14,
#             160.23,
#             176.57,
#             178.65,
#             182.16,
#             208.55,
#             218.76,
#             226.84,
#             231.88,
#             240.84,
#             258.5,
#             264.33,
#             270.73,
#             277.75,
#             286.39
#         ],
#         "end_timestamps": [
#             7.5,
#             30.06,
#             34.77,
#             45.06,
#             83.73,
#             85.09,
#             98.88,
#             130.82,
#             134.49,
#             151.65,
#             158.68,
#             171.38,
#             177.21,
#             179.51,
#             183.34,
#             212.55,
#             221.32,
#             228.08,
#             232.66,
#             245.0,
#             259.5,
#             269.13,
#             274.45,
#             280.17,
#             287.0
#         ]
#     },
#     "2": {
#         "speakerId": "2",
#         "start_timestamps": [
#             8.37,
#             21.58,
#             34.91,
#             134.49,
#             142.58,
#             147.22,
#             151.65,
#             172.82,
#             184.09,
#             186.91,
#             189.08,
#             197.02,
#             199.38,
#             214.4,
#             221.61,
#             228.36,
#             235.29,
#             238.69,
#             245.63,
#             259.5,
#             274.45,
#             280.96,
#             287.71
#         ],
#         "end_timestamps": [
#             21.03,
#             23.41,
#             37.23,
#             140.93,
#             144.37,
#             148.75,
#             152.03,
#             176.21,
#             186.14,
#             187.24,
#             193.35,
#             197.59,
#             206.44,
#             217.73,
#             225.43,
#             231.52,
#             236.11,
#             239.31,
#             258.48,
#             262.73,
#             277.37,
#             283.51,
#             288.07
#         ]
#     }
# }

# %%
import urllib.request

#download the file to a local dir
urllib.request.urlretrieve('https://gtsblob.blob.core.windows.net/transcription/Samoy.wav', 'Samoy.wav')
# Out:
# ('Samoy.wav', <http.client.HTTPMessage at 0x13c99537b70>)

# %%
# !pip install pydub
import os
from pydub import AudioSegment

for speaker in speakers:
  element = speakers_timestamps[speaker]

  for i in range(len(element['start_timestamps'])):
    newAudio = AudioSegment.from_wav("Samoy.wav")
    newAudio = newAudio[int(element['start_timestamps'][i]*1000):int(element['end_timestamps'][i]*1000)]
    newAudio.export('newSong' + str(i) + '.wav', format="wav")

  combined_sounds = AudioSegment.from_wav("newSong0.wav")
  
  for i in range(len(element['start_timestamps'])):
    sound = AudioSegment.from_wav("newSong" + str(i) + ".wav")
    combined_sounds = combined_sounds + sound
    combined_sounds.export('newClip' + element['speakerId'] + '.wav', format="wav")

  for i in range(len(element['start_timestamps'])):
    os.remove('newSong' + str(i) + '.wav')
# Out:
# Requirement already satisfied: pydub in c:\programdata\anaconda3\lib\site-packages (0.24.1)
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
